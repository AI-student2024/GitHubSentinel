# %% [markdown]
# # 获取 GitHub 项目进展
#
# 以下代码主要由 GPT-4 生成，演示 `GitHubClient` 模块的版本演进。
#
#
# ## 使用 GitHub REST API 获取项目信息
#
# GitHub REST API 为开发者提供了便捷获取 GitHub 项目的丰富 API。
#
# ![Github Docs](images/github_docs.png)
#
# 例如，获取项目 issues 列表，GitHub 提供了 `"List repository issues"` API。
#
#
# ## GitHub Token 配置
#
# 使用 `GitHubClient` 模块调用 GitHub REST API 需要配置 [GitHub Fine-grained personal access token](https://github.com/settings/tokens?type=beta)。
#
# - **配置文件**：正式启动 GitHubSentinel 项目，可以替换 `config.json` 中 `github_token` 值。
# - **Jupyter测试**：在使用构造函数实例化 GitHubClient 类，以参数形式传入。
#
# 下面以 https://github.com/langchain-ai/langchain 项目为例，演示 GitHubClient 使用方法

# %% [markdown]
# ## [v0.2] GitHubClient Class

# %%
# src/github_client.py

import requests  # 导入requests库用于发起HTTP请求
import datetime  # 导入datetime库处理日期和时间

class GitHubClient:
    def __init__(self, token):
        self.token = token  # GitHub的访问令牌
        # 初始化请求头部，这里主要是为了使用GitHub的API进行身份验证
        self.headers = {'Authorization': f'token {self.token}'}

    def fetch_updates(self, repos):
        # 为给定的仓库列表获取更新，包括提交、问题和拉取请求
        updates = {}
        for repo in repos:
            # 遍历每个仓库并获取相关信息
            updates[repo] = {
                'commits': self.fetch_commits(repo),  # 获取提交记录
                'issues': self.fetch_issues(repo),   # 获取问题
                'pull_requests': self.fetch_pull_requests(repo)  # 获取拉取请求
            }
        return updates

    def fetch_commits(self, repo):
        # 构建获取提交记录的API URL
        url = f'https://api.github.com/repos/{repo}/commits'
        response = requests.get(url, headers=self.headers)
        response.raise_for_status()  # 检查请求是否成功，如果出错则抛出异常
        return response.json()  # 返回解析JSON格式的数据

    def fetch_issues(self, repo):
        # 构建获取问题(issue)的API URL
        url = f'https://api.github.com/repos/{repo}/issues'
        response = requests.get(url, headers=self.headers)
        response.raise_for_status()  # 确保响应没有HTTP错误
        return response.json()  # 返回JSON数据

    def fetch_pull_requests(self, repo):
        # 构建获取拉取请求(pull requests)的API URL
        url = f'https://api.github.com/repos/{repo}/pulls'
        response = requests.get(url, headers=self.headers)
        response.raise_for_status()
        return response.json()  # 返回JSON格式的拉取请求数据

    def export_daily_progress(self, repo):
        # 导出指定仓库的每日进度，包括问题和拉取请求
        date_str = datetime.datetime.now().strftime('%Y-%m-%d')  # 获取当前日期字符串
        issues = self.fetch_issues(repo)  # 获取当天的问题
        pull_requests = self.fetch_pull_requests(repo)  # 获取当天的拉取请求
        filename = f"{repo.replace('/', '_')}_{date_str}.md"  # 根据仓库名和日期生成文件名

        # 打开文件进行写入
        with open(filename, 'w') as f:
            f.write(f"# {repo} Daily Progress - {date_str}\n\n")  # 写入标题
            f.write("## Issues\n")
            for issue in issues:
                f.write(f"- {issue['title']} #{issue['number']}\n")  # 列出每个问题
            f.write("\n## Pull Requests\n")
            for pr in pull_requests:
                f.write(f"- {pr['title']} #{pr['number']}\n")  # 列出每个拉取请求

        print(f"Exported daily progress to {filename}")  # 打印导出信息

        return filename

# %% [markdown]
# ### 实例化 GitHubClient
#
# 从环境变量中获取 `GITHUB_TOKEN`，依次获取 Commits, Issues 和 Pull Requests。

# %%
import os

github_client = GitHubClient(token=os.getenv("GITHUB_TOKEN"))

# %% [markdown]
# ### List Issues API
#
# API完整文档说明见：https://docs.github.com/en/rest/issues/issues?apiVersion=2022-11-28#list-repository-issues
#
# **请求样例**：`GET /repos/{owner}/{repo}/issues`;
#
# **返回样例**：
#
# ```json
# [
#   {
#     "id": 1,
#     "node_id": "MDU6SXNzdWUx",
#     "url": "https://api.github.com/repos/octocat/Hello-World/issues/1347",
#     "repository_url": "https://api.github.com/repos/octocat/Hello-World",
#     "labels_url": "https://api.github.com/repos/octocat/Hello-World/issues/1347/labels{/name}",
#     "comments_url": "https://api.github.com/repos/octocat/Hello-World/issues/1347/comments",
#     "events_url": "https://api.github.com/repos/octocat/Hello-World/issues/1347/events",
#     "html_url": "https://github.com/octocat/Hello-World/issues/1347",
#     "number": 1347,
#     "state": "open",
#     "title": "Found a bug",
#     "body": "I'm having a problem with this.",
#     "user": {
#       "login": "octocat",
#       "id": 1,
#       "node_id": "MDQ6VXNlcjE=",
#       "avatar_url": "https://github.com/images/error/octocat_happy.gif",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/octocat",
#       "html_url": "https://github.com/octocat",
#       "followers_url": "https://api.github.com/users/octocat/followers",
#       "following_url": "https://api.github.com/users/octocat/following{/other_user}",
#       "gists_url": "https://api.github.com/users/octocat/gists{/gist_id}",
#       "starred_url": "https://api.github.com/users/octocat/starred{/owner}{/repo}",
#       "subscriptions_url": "https://api.github.com/users/octocat/subscriptions",
#       "organizations_url": "https://api.github.com/users/octocat/orgs",
#       "repos_url": "https://api.github.com/users/octocat/repos",
#       "events_url": "https://api.github.com/users/octocat/events{/privacy}",
#       "received_events_url": "https://api.github.com/users/octocat/received_events",
#       "type": "User",
#       "site_admin": false
#     },
#     "labels": [
#       {
#         "id": 208045946,
#         "node_id": "MDU6TGFiZWwyMDgwNDU5NDY=",
#         "url": "https://api.github.com/repos/octocat/Hello-World/labels/bug",
#         "name": "bug",
#         "description": "Something isn't working",
#         "color": "f29513",
#         "default": true
#       }
#     ],
#     "assignee": {
#       "login": "octocat",
#       "id": 1,
#       "node_id": "MDQ6VXNlcjE=",
#       "avatar_url": "https://github.com/images/error/octocat_happy.gif",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/octocat",
#       "html_url": "https://github.com/octocat",
#       "followers_url": "https://api.github.com/users/octocat/followers",
#       "following_url": "https://api.github.com/users/octocat/following{/other_user}",
#       "gists_url": "https://api.github.com/users/octocat/gists{/gist_id}",
#       "starred_url": "https://api.github.com/users/octocat/starred{/owner}{/repo}",
#       "subscriptions_url": "https://api.github.com/users/octocat/subscriptions",
#       "organizations_url": "https://api.github.com/users/octocat/orgs",
#       "repos_url": "https://api.github.com/users/octocat/repos",
#       "events_url": "https://api.github.com/users/octocat/events{/privacy}",
#       "received_events_url": "https://api.github.com/users/octocat/received_events",
#       "type": "User",
#       "site_admin": false
#     },
#     "assignees": [
#       {
#         "login": "octocat",
#         "id": 1,
#         "node_id": "MDQ6VXNlcjE=",
#         "avatar_url": "https://github.com/images/error/octocat_happy.gif",
#         "gravatar_id": "",
#         "url": "https://api.github.com/users/octocat",
#         "html_url": "https://github.com/octocat",
#         "followers_url": "https://api.github.com/users/octocat/followers",
#         "following_url": "https://api.github.com/users/octocat/following{/other_user}",
#         "gists_url": "https://api.github.com/users/octocat/gists{/gist_id}",
#         "starred_url": "https://api.github.com/users/octocat/starred{/owner}{/repo}",
#         "subscriptions_url": "https://api.github.com/users/octocat/subscriptions",
#         "organizations_url": "https://api.github.com/users/octocat/orgs",
#         "repos_url": "https://api.github.com/users/octocat/repos",
#         "events_url": "https://api.github.com/users/octocat/events{/privacy}",
#         "received_events_url": "https://api.github.com/users/octocat/received_events",
#         "type": "User",
#         "site_admin": false
#       }
#     ],
#     "milestone": {
#       "url": "https://api.github.com/repos/octocat/Hello-World/milestones/1",
#       "html_url": "https://github.com/octocat/Hello-World/milestones/v1.0",
#       "labels_url": "https://api.github.com/repos/octocat/Hello-World/milestones/1/labels",
#       "id": 1002604,
#       "node_id": "MDk6TWlsZXN0b25lMTAwMjYwNA==",
#       "number": 1,
#       "state": "open",
#       "title": "v1.0",
#       "description": "Tracking milestone for version 1.0",
#       "creator": {
#         "login": "octocat",
#         "id": 1,
#         "node_id": "MDQ6VXNlcjE=",
#         "avatar_url": "https://github.com/images/error/octocat_happy.gif",
#         "gravatar_id": "",
#         "url": "https://api.github.com/users/octocat",
#         "html_url": "https://github.com/octocat",
#         "followers_url": "https://api.github.com/users/octocat/followers",
#         "following_url": "https://api.github.com/users/octocat/following{/other_user}",
#         "gists_url": "https://api.github.com/users/octocat/gists{/gist_id}",
#         "starred_url": "https://api.github.com/users/octocat/starred{/owner}{/repo}",
#         "subscriptions_url": "https://api.github.com/users/octocat/subscriptions",
#         "organizations_url": "https://api.github.com/users/octocat/orgs",
#         "repos_url": "https://api.github.com/users/octocat/repos",
#         "events_url": "https://api.github.com/users/octocat/events{/privacy}",
#         "received_events_url": "https://api.github.com/users/octocat/received_events",
#         "type": "User",
#         "site_admin": false
#       },
#       "open_issues": 4,
#       "closed_issues": 8,
#       "created_at": "2011-04-10T20:09:31Z",
#       "updated_at": "2014-03-03T18:58:10Z",
#       "closed_at": "2013-02-12T13:22:01Z",
#       "due_on": "2012-10-09T23:39:01Z"
#     },
#     "locked": true,
#     "active_lock_reason": "too heated",
#     "comments": 0,
#     "pull_request": {
#       "url": "https://api.github.com/repos/octocat/Hello-World/pulls/1347",
#       "html_url": "https://github.com/octocat/Hello-World/pull/1347",
#       "diff_url": "https://github.com/octocat/Hello-World/pull/1347.diff",
#       "patch_url": "https://github.com/octocat/Hello-World/pull/1347.patch"
#     },
#     "closed_at": null,
#     "created_at": "2011-04-22T13:33:48Z",
#     "updated_at": "2011-04-22T13:33:48Z",
#     "closed_by": {
#       "login": "octocat",
#       "id": 1,
#       "node_id": "MDQ6VXNlcjE=",
#       "avatar_url": "https://github.com/images/error/octocat_happy.gif",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/octocat",
#       "html_url": "https://github.com/octocat",
#       "followers_url": "https://api.github.com/users/octocat/followers",
#       "following_url": "https://api.github.com/users/octocat/following{/other_user}",
#       "gists_url": "https://api.github.com/users/octocat/gists{/gist_id}",
#       "starred_url": "https://api.github.com/users/octocat/starred{/owner}{/repo}",
#       "subscriptions_url": "https://api.github.com/users/octocat/subscriptions",
#       "organizations_url": "https://api.github.com/users/octocat/orgs",
#       "repos_url": "https://api.github.com/users/octocat/repos",
#       "events_url": "https://api.github.com/users/octocat/events{/privacy}",
#       "received_events_url": "https://api.github.com/users/octocat/received_events",
#       "type": "User",
#       "site_admin": false
#     },
#     "author_association": "COLLABORATOR",
#     "state_reason": "completed"
#   }
# ]
# ```

# %%
repo = "langchain-ai/langchain"

# %%
issues = github_client.fetch_issues(repo)

# %% [markdown]
# ### GitHubClient fetch 方法 repo 参数格式要求
#
# 从 GitHub 获取项目进展，需要访问形如 `https://api.github.com/repos/{repo}/issues`(以issues为例）的 URL。因此，repo 必须符合 GitHub Repo 标准命名，如下所示:
#
# ```json
# [
#     "langchain-ai/langchain",
#     "DjangoPeng/openai-quickstart",
#     "ollama/ollama"
# ]
# ```
#
# **GitHubSentinel 项目订阅管理配置文件为 `subscriptions.json`。**

# %%
issues
# Out:
# [{'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25652',
#   'repository_url': 'https://api.github.com/repos/langchain-ai/langchain',
#   'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25652/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25652/comments',
#   'events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25652/events',
#   'html_url': 'https://github.com/langchain-ai/langchain/pull/25652',
#   'id': 2479718185,
#   'node_id': 'PR_kwDOIPDwls55EhB8',
#   'number': 25652,
#   'title': '[community] Support passing extra params for executing functions in UCFunctionToolkit',
#   'user': {'login': 'serena-ruan',
#    'id': 82044803,
#    'node_id': 'MDQ6VXNlcjgyMDQ0ODAz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/82044803?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/serena-ruan',
#    'html_url': 'https://github.com/serena-ruan',
#    'followers_url': 'https://api.github.com/users/serena-ruan/followers',
#    'following_url': 'https://api.github.com/users/serena-ruan/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/serena-ruan/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/serena-ruan/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/serena-ruan/subscriptions',
#    'organizations_url': 'https://api.github.com/users/serena-ruan/orgs',
#    'repos_url': 'https://api.github.com/users/serena-ruan/repos',
#    'events_url': 'https://api.github.com/users/serena-ruan/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/serena-ruan/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 5680700873,
#     'node_id': 'LA_kwDOIPDwls8AAAABUpidyQ',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%F0%9F%A4%96:improvement',
#     'name': '🤖:improvement',
#     'color': 'C5DEF5',
#     'default': False,
#     'description': 'Medium size change to existing code to handle new use-cases'},
#    {'id': 6232714126,
#     'node_id': 'LA_kwDOIPDwls8AAAABc3-rjg',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/size:L',
#     'name': 'size:L',
#     'color': 'F9D0C4',
#     'default': False,
#     'description': 'This PR changes 100-499 lines, ignoring generated files.'},
#    {'id': 7097373342,
#     'node_id': 'LA_kwDOIPDwls8AAAABpwlSng',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/community',
#     'name': 'community',
#     'color': '579082',
#     'default': False,
#     'description': 'Related to langchain-community'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2024-08-22T04:06:47Z',
#   'updated_at': '2024-08-22T04:07:32Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25652',
#    'html_url': 'https://github.com/langchain-ai/langchain/pull/25652',
#    'diff_url': 'https://github.com/langchain-ai/langchain/pull/25652.diff',
#    'patch_url': 'https://github.com/langchain-ai/langchain/pull/25652.patch',
#    'merged_at': None},
#   'body': 'Thank you for contributing to LangChain!\r\n\r\n- [x] **PR title**: "package: description"\r\n  - Where "package" is whichever of langchain, community, core, experimental, etc. is being modified. Use "docs: ..." for purely docs changes, "templates: ..." for template changes, "infra: ..." for CI changes.\r\n  - Example: "community: add foobar LLM"\r\n\r\n\r\nSupport passing extra params when executing UC functions:\r\nThe params should be a dictionary with key EXECUTE_FUNCTION_ARG_NAME, the assumption is that the function itself doesn\'t use such variable name (starting and ending with double underscores), and if it does we raise Exception.\r\nIf invalid params passing to the execute_statement, we raise Exception as well.\r\n\r\n\r\n- [x] **Add tests and docs**: If you\'re adding a new integration, please include\r\n  1. a test for the integration, preferably unit tests that do not rely on network access,\r\n  2. an example notebook showing its use. It lives in `docs/docs/integrations` directory.\r\n\r\n\r\n- [x] **Lint and test**: Run `make format`, `make lint` and `make test` from the root of the package(s) you\'ve modified. See contribution guidelines for more: https://python.langchain.com/docs/contributing/\r\n\r\nAdditional guidelines:\r\n- Make sure optional dependencies are imported within a function.\r\n- Please do not add dependencies to pyproject.toml files (even optional ones) unless they are required for unit tests.\r\n- Most PRs should not touch more than one package.\r\n- Changes should be backwards compatible.\r\n- If you are adding something to community, do not re-import it in langchain.\r\n\r\nIf no one reviews your PR within a few days, please @-mention one of baskaryan, efriis, eyurtsev, ccurme, vbarda, hwchase17.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25652/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25652/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25651',
#   'repository_url': 'https://api.github.com/repos/langchain-ai/langchain',
#   'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25651/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25651/comments',
#   'events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25651/events',
#   'html_url': 'https://github.com/langchain-ai/langchain/issues/25651',
#   'id': 2479699061,
#   'node_id': 'I_kwDOIPDwls6TzTR1',
#   'number': 25651,
#   'title': 'chroma impl issue',
#   'user': {'login': 'tkb1902',
#    'id': 138828337,
#    'node_id': 'U_kgDOCEZaMQ',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/138828337?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tkb1902',
#    'html_url': 'https://github.com/tkb1902',
#    'followers_url': 'https://api.github.com/users/tkb1902/followers',
#    'following_url': 'https://api.github.com/users/tkb1902/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/tkb1902/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/tkb1902/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/tkb1902/subscriptions',
#    'organizations_url': 'https://api.github.com/users/tkb1902/orgs',
#    'repos_url': 'https://api.github.com/users/tkb1902/repos',
#    'events_url': 'https://api.github.com/users/tkb1902/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/tkb1902/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 5680700839,
#     'node_id': 'LA_kwDOIPDwls8AAAABUpidpw',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%F0%9F%A4%96:bug',
#     'name': '🤖:bug',
#     'color': 'F9D0C4',
#     'default': False,
#     'description': 'Related to a bug, vulnerability, unexpected error with an existing feature'},
#    {'id': 5924999838,
#     'node_id': 'LA_kwDOIPDwls8AAAABYShSng',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%F0%9F%94%8C:%20chroma',
#     'name': '🔌: chroma',
#     'color': 'BFD4F2',
#     'default': False,
#     'description': 'Primarily related to ChromaDB integrations'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2024-08-22T03:44:55Z',
#   'updated_at': '2024-08-22T03:47:28Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Checked other resources\n\n- [X] I added a very descriptive title to this issue.\n- [X] I searched the LangChain documentation with the integrated search.\n- [X] I used the GitHub search to find a similar question and didn\'t find it.\n- [X] I am sure that this is a bug in LangChain rather than my code.\n- [X] The bug is not resolved by updating to the latest stable version of LangChain (or the specific integration package).\n\n### Example Code\n\n\'\'\'python\r\nimport HuggingFaceEmbeddings\r\nfrom langchain_community.document_loaders import DirectoryLoader, PDFMinerLoader, PyPDFLoader\r\nfrom langchain_text_splitters import RecursiveCharacterTextSplitter\r\nfrom langchain_community.vectorstores import Chroma\r\nfrom constants import CHROMA_SETTINGS\r\n\r\npersist_directory = "db"\r\n\r\ndef main():\r\n    for root, dirs, files in os.walk("docs"):\r\n        for file in files:\r\n            if file.endswith(".pdf"):\r\n                print(file)\r\n                loader = PyPDFLoader(os.path.join(root, file))\r\n                documents = loader.load()  # Moved inside the if statement to ensure documents are loaded only for PDFs\r\n                print("splitting into chunks")\r\n                text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=100)\r\n                texts = text_splitter.split_documents(documents)\r\n                # create embeddings here\r\n                print("Loading sentence transformers model")\r\n                embeddings =HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")\r\n                # create vector store here\r\n                print(f"Creating embeddings. May take some minutes...")\r\n                db = Chroma.from_documents(texts, embeddings, persist_directory=persist_directory, client_settings=CHROMA_SETTINGS)\r\n                db.persist()\r\n                db = None\r\n\r\n    print(f"Ingestion complete! You can now run privateGPT.py to query your documents")\r\n\r\nif __name__ == "__main__":\r\n    main()\r\n\'\'\'\n\n### Error Message and Stack Trace (if applicable)\n\n(env) PS C:\\Users\\USER\\Documents\\models\\chatToPdf\\Chat-with-PDF-Chatbot> & c:/Users/USER/Documents/models/chatToPdf/Chat-with-PDF-Chatbot/env/Scripts/python.exe c:/Users/USER/Documents/models/chatToPdf/Chat-with-PDF-Chatbot/ingest.py\r\nduckdb+parquet\r\ndb\r\nTrue\r\nApplied Natural Language Processing with Python_ Implementing Machine Learning and Deep Learning Algorithms for Natural Language Processing ( PDFDrive ).pdf\r\nsplitting into chunks\r\nLoading sentence transformers model\r\nC:\\Users\\USER\\Documents\\models\\chatToPdf\\Chat-with-PDF-Chatbot\\env\\Lib\\site-packages\\transformers\\tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to \r\n`True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884\r\n  warnings.warn(\r\nCreating embeddings. May take some minutes...\r\nTraceback (most recent call last):\r\n  File "c:\\Users\\USER\\Documents\\models\\chatToPdf\\Chat-with-PDF-Chatbot\\ingest.py", line 32, in <module>\r\n    main()\r\n  File "c:\\Users\\USER\\Documents\\models\\chatToPdf\\Chat-with-PDF-Chatbot\\ingest.py", line 25, in main\r\n    db = Chroma.from_documents(texts, embeddings, persist_directory=persist_directory, client_settings=CHROMA_SETTINGS)\r\n         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\r\n  File "C:\\Users\\USER\\Documents\\models\\chatToPdf\\Chat-with-PDF-Chatbot\\env\\Lib\\site-packages\\langchain_community\\vectorstores\\chroma.py", line 878, in from_documents\r\n    return cls.from_texts(\r\ntings)\r\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^env\\Lib\\site-packages\\langchain_community\\vectorstores\\chroma.py", line 8 ...
#   'reactions': {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25651/reactions',
#    'total_count': 1,
#    '+1': 1,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25651/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25650',
#   'repository_url': 'https://api.github.com/repos/langchain-ai/langchain',
#   'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25650/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25650/comments',
#   'events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25650/events',
#   'html_url': 'https://github.com/langchain-ai/langchain/pull/25650',
#   'id': 2479686140,
#   'node_id': 'PR_kwDOIPDwls55EaTn',
#   'number': 25650,
#   'title': 'docs: sorted Templates menu',
#   'user': {'login': 'leo-gan',
#    'id': 2256422,
#    'node_id': 'MDQ6VXNlcjIyNTY0MjI=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2256422?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/leo-gan',
#    'html_url': 'https://github.com/leo-gan',
#    'followers_url': 'https://api.github.com/users/leo-gan/followers',
#    'following_url': 'https://api.github.com/users/leo-gan/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/leo-gan/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/leo-gan/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/leo-gan/subscriptions',
#    'organizations_url': 'https://api.github.com/users/leo-gan/orgs',
#    'repos_url': 'https://api.github.com/users/leo-gan/repos',
#    'events_url': 'https://api.github.com/users/leo-gan/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/leo-gan/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2024-08-22T03:29:26Z',
#   'updated_at': '2024-08-22T03:35:07Z',
#   'closed_at': None,
#   'author_association': 'COLLABORATOR',
#   'active_lock_reason': None,
#   'draft': True,
#   'pull_request': {'url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25650',
#    'html_url': 'https://github.com/langchain-ai/langchain/pull/25650',
#    'diff_url': 'https://github.com/langchain-ai/langchain/pull/25650.diff',
#    'patch_url': 'https://github.com/langchain-ai/langchain/pull/25650.patch',
#    'merged_at': None},
#   'body': 'The Templates menu is sorted by the file names.\r\nI want to sort in by the Titles (where Title is a line, started with "# " (H1)).',
#   'reactions': {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25650/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25650/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25649',
#   'repository_url': 'https://api.github.com/repos/langchain-ai/langchain',
#   'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25649/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25649/comments',
#   'events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25649/events',
#   'html_url': 'https://github.com/langchain-ai/langchain/pull/25649',
#   'id': 2479490160,
#   'node_id': 'PR_kwDOIPDwls55D4f8',
#   'number': 25649,
#   'title': 'docs: Change Pull Request to Merge Request in GitLab notebook',
#   'user': {'login': 'DylanGriffith',
#    'id': 1002737,
#    'node_id': 'MDQ6VXNlcjEwMDI3Mzc=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1002737?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/DylanGriffith',
#    'html_url': 'https://github.com/DylanGriffith',
#    'followers_url': 'https://api.github.com/users/DylanGriffith/followers',
#    'following_url': 'https://api.github.com/users/DylanGriffith/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/DylanGriffith/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/DylanGriffith/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/DylanGriffith/subscriptions',
#    'organizations_url': 'https://api.github.com/users/DylanGriffith/orgs',
#    'repos_url': 'https://api.github.com/users/DylanGriffith/repos',
#    'events_url': 'https://api.github.com/users/DylanGriffith/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/DylanGriffith/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 5680700918,
#     'node_id': 'LA_kwDOIPDwls8AAAABUpid9g',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%F0%9F%A4%96:docs',
#     'name': '🤖:docs',
#     'color': 'C5DEF5',
#     'default': False,
#     'description': 'Changes to documentation and examples, like .md, .rst, .ipynb files. Changes to the docs/ folder'},
#    {'id': 6232714108,
#     'node_id': 'LA_kwDOIPDwls8AAAABc3-rfA',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/size:S',
#     'name': 'size:S',
#     'color': 'BFDADC',
#     'default': False,
#     'description': 'This PR changes 10-29 lines, ignoring generated files.'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2024-08-22T00:59:10Z',
#   'updated_at': '2024-08-22T01:11:42Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25649',
#    'html_url': 'https://github.com/langchain-ai/langchain/pull/25649',
#    'diff_url': 'https://github.com/langchain-ai/langchain/pull/25649.diff',
#    'patch_url': 'https://github.com/langchain-ai/langchain/pull/25649.patch',
#    'merged_at': None},
#   'body': '- **Description:** In GitLab we call these "merge requests" rather than "pull requests" so I thought I\'d go ahead and update the notebook.\r\n- **Issue:** N/A\r\n- **Dependencies:** none\r\n- **Twitter handle:** N/A\r\n\r\nThanks for creating the tools and notebook to help people work with GitLab. I thought I\'d contribute some minor docs updates here.',
#   'reactions': {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25649/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25649/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25648',
#   'repository_url': 'https://api.github.com/repos/langchain-ai/langchain',
#   'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25648/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25648/comments',
#   'events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25648/events',
#   'html_url': 'https://github.com/langchain-ai/langchain/pull/25648',
#   'id': 2479475256,
#   'node_id': 'PR_kwDOIPDwls55D1S8',
#   'number': 25648,
#   'title': 'Databricks partner package 2',
#   'user': {'login': 'B-Step62',
#    'id': 31463517,
#    'node_id': 'MDQ6VXNlcjMxNDYzNTE3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/31463517?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/B-Step62',
#    'html_url': 'https://github.com/B-Step62',
#    'followers_url': 'https://api.github.com/users/B-Step62/followers',
#    'following_url': 'https://api.github.com/users/B-Step62/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/B-Step62/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/B-Step62/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/B-Step62/subscriptions',
#    'organizations_url': 'https://api.github.com/users/B-Step62/orgs',
#    'repos_url': 'https://api.github.com/users/B-Step62/repos',
#    'events_url': 'https://api.github.com/users/B-Step62/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/B-Step62/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 5541141061,
#     'node_id': 'LA_kwDOIPDwls8AAAABSkcaRQ',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%E2%B1%AD:%20embeddings',
#     'name': 'Ɑ: embeddings',
#     'color': 'D4C5F9',
#     'default': False,
#     'description': 'Related to text embedding models module'},
#    {'id': 5541432778,
#     'node_id': 'LA_kwDOIPDwls8AAAABSkuNyg',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%E2%B1%AD:%20vector%20store',
#     'name': 'Ɑ: vector store',
#     'color': 'D4C5F9',
#     'default': False,
#     'description': 'Related to vector store module'},
#    {'id': 5680700863,
#     'node_id': 'LA_kwDOIPDwls8AAAABUpidvw',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%F0%9F%A4%96:enhancement',
#     'name': '🤖:enhancement',
#     'color': 'C5DEF5',
#     'default': False,
#     'description': 'A large net-new component, integration, or chain. Use sparingly. The largest features'},
#    {'id': 6232714144,
#     'node_id': 'LA_kwDOIPDwls8AAAABc3-roA',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/size:XXL',
#     'name': 'size:XXL',
#     'color': 'D93F0B',
#     'default': False,
#     'description': 'This PR changes 1000+ lines, ignoring generated files.'},
#    {'id': 6348691034,
#     'node_id': 'LA_kwDOIPDwls8AAAABemlWWg',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/partner',
#     'name': 'partner',
#     'color': 'ededed',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': {'login': 'efriis',
#    'id': 9557659,
#    'node_id': 'MDQ6VXNlcjk1NTc2NTk=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/9557659?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/efriis',
#    'html_url': 'https://github.com/efriis',
#    'followers_url': 'https://api.github.com/users/efriis/followers',
#    'following_url': 'https://api.github.com/users/efriis/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/efriis/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/efriis/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/efriis/subscriptions',
#    'organizations_url': 'https://api.github.com/users/efriis/orgs',
#    'repos_url': 'https://api.github.com/users/efriis/repos',
#    'events_url': 'https://api.github.com/users/efriis/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/efriis/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'assignees': [{'login': 'efriis',
#     'id': 9557659,
#     'node_id': 'MDQ6VXNlcjk1NTc2NTk=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/9557659?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/efriis',
#     'html_url': 'https://github.com/efriis',
#     'followers_url': 'https://api.github.com/users/efriis/followers',
#     'following_url': 'https://api.github.com/users/efriis/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/efriis/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/efriis/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/efriis/subscriptions',
#     'organizations_url': 'https://api.github.com/users/efriis/orgs',
#     'repos_url': 'https://api.github.com/users/efriis/repos',
#     'events_url': 'https://api.github.com/users/efriis/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/efriis/received_events',
#     'type': 'User',
#     'site_admin': False}],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2024-08-22T00:39:16Z',
#   'updated_at': '2024-08-22T00:40:21Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25648',
#    'html_url': 'https://github.com/langchain-ai/langchain/pull/25648',
#    'diff_url': 'https://github.com/langchain-ai/langchain/pull/25648.diff',
#    'patch_url': 'https://github.com/langchain-ai/langchain/pull/25648.patch',
#    'merged_at': None},
#   'body': '### Summary\r\n\r\nAdd `DatabricksVectorSearch` and `DatabricksEmbeddings` classes to the `langchain-databricks` partner packages. Core functionality is unchanged, but the vector search class is largely refactored for readability and maintainability.\r\n\r\nThis PR does not add integration tests yet. This will be added once the Databricks test workspace is ready.\r\n\r\nTagging @efriis as POC\r\n\r\n\r\n### Tracker\r\n[✅] Create a package and imgrate ChatDatabricks\r\n[✍️] Migrate DatabricksVectorSearch, DatabricksEmbeddings, and their docs\r\n~[ ] Migrate UCFunctionToolkit and its doc~\r\n[ ] Add provider document and update README.md\r\n[ ] Add integration tests and set up secrets (after moved to an external package)\r\n[ ] Add deprecation note to the community implementations.',
#   'reactions': {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25648/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25648/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25647',
#   'repository_url': 'https://api.github.com/repos/langchain-ai/langchain',
#   'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25647/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25647/comments',
#   'events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25647/events',
#   'html_url': 'https://github.com/langchain-ai/langchain/pull/25647',
#   'id': 2479465337,
#   'node_id': 'PR_kwDOIPDwls55DzIX',
#   'number': 25647,
#   'title': 'docs: Updated WikipediaLoader documentation',
#   'user': {'login': 'parsa-abbasi',
#    'id': 26406638,
#    'node_id': 'MDQ6VXNlcjI2NDA2NjM4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26406638?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/parsa-abbasi',
#    'html_url': 'https://github.com/parsa-abbasi',
#    'followers_url': 'https://api.github.com/users/parsa-abbasi/followers',
#    'following_url': 'https://api.github.com/users/parsa-abbasi/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/parsa-abbasi/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/parsa-abbasi/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/parsa-abbasi/subscriptions',
#    'organizations_url': 'https://api.github.com/users/parsa-abbasi/orgs',
#    'repos_url': 'https://api.github.com/users/parsa-abbasi/repos',
#    'events_url': 'https://api.github.com/users/parsa-abbasi/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/parsa-abbasi/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 5680700918,
#     'node_id': 'LA_kwDOIPDwls8AAAABUpid9g',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%F0%9F%A4%96:docs',
#     'name': '🤖:docs',
#     'color': 'C5DEF5',
#     'default': False,
#     'description': 'Changes to documentation and examples, like .md, .rst, .ipynb files. Changes to the docs/ folder'},
#    {'id': 6232714119,
#     'node_id': 'LA_kwDOIPDwls8AAAABc3-rhw',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/size:M',
#     'name': 'size:M',
#     'color': 'FEF2C0',
#     'default': False,
#     'description': 'This PR changes 30-99 lines, ignoring generated files.'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2024-08-22T00:27:02Z',
#   'updated_at': '2024-08-22T00:39:40Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25647',
#    'html_url': 'https://github.com/langchain-ai/langchain/pull/25647',
#    'diff_url': 'https://github.com/langchain-ai/langchain/pull/25647.diff',
#    'patch_url': 'https://github.com/langchain-ai/langchain/pull/25647.patch',
#    'merged_at': None},
#   'body': '- Output of the cells was not included in the documentation. I have added them.\r\n- There is another parameter in the `WikipediaLoader` class called `doc_content_chars_max` (Based on [this](https://api.python.langchain.com/en/latest/document_loaders/langchain_community.document_loaders.wikipedia.WikipediaLoader.html)). I have included this in the list of parameters.\r\n- I put the list of parameters under a new section called "Parameters" in the documentation.\r\n- I also included the `langchain_community` package in the installation command.\r\n- Some minor formatting/spelling issues were fixed.',
#   'reactions': {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25647/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25647/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25646',
#   'repository_url': 'https://api.github.com/repos/langchain-ai/langchain',
#   'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25646/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25646/comments',
#   'events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25646/events',
#   'html_url': 'https://github.com/langchain-ai/langchain/pull/25646',
#   'id': 2479434789,
#   'node_id': 'PR_kwDOIPDwls55DsiR',
#   'number': 25646,
#   'title': 'docs: `templates` updated titles',
#   'user': {'login': 'leo-gan',
#    'id': 2256422,
#    'node_id': 'MDQ6VXNlcjIyNTY0MjI=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2256422?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/leo-gan',
#    'html_url': 'https://github.com/leo-gan',
#    'followers_url': 'https://api.github.com/users/leo-gan/followers',
#    'following_url': 'https://api.github.com/users/leo-gan/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/leo-gan/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/leo-gan/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/leo-gan/subscriptions',
#    'organizations_url': 'https://api.github.com/users/leo-gan/orgs',
#    'repos_url': 'https://api.github.com/users/leo-gan/repos',
#    'events_url': 'https://api.github.com/users/leo-gan/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/leo-gan/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 5680700918,
#     'node_id': 'LA_kwDOIPDwls8AAAABUpid9g',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%F0%9F%A4%96:docs',
#     'name': '🤖:docs',
#     'color': 'C5DEF5',
#     'default': False,
#     'description': 'Changes to documentation and examples, like .md, .rst, .ipynb files. Changes to the docs/ folder'},
#    {'id': 6154420538,
#     'node_id': 'LA_kwDOIPDwls8AAAABbtUBOg',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/template',
#     'name': 'template',
#     'color': '145FB1',
#     'default': False,
#     'description': ''},
#    {'id': 6232714126,
#     'node_id': 'LA_kwDOIPDwls8AAAABc3-rjg',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/size:L',
#     'name': 'size:L',
#     'color': 'F9D0C4',
#     'default': False,
#     'description': 'This PR changes 100-499 lines, ignoring generated files.'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': {'login': 'efriis',
#    'id': 9557659,
#    'node_id': 'MDQ6VXNlcjk1NTc2NTk=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/9557659?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/efriis',
#    'html_url': 'https://github.com/efriis',
#    'followers_url': 'https://api.github.com/users/efriis/followers',
#    'following_url': 'https://api.github.com/users/efriis/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/efriis/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/efriis/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/efriis/subscriptions',
#    'organizations_url': 'https://api.github.com/users/efriis/orgs',
#    'repos_url': 'https://api.github.com/users/efriis/repos',
#    'events_url': 'https://api.github.com/users/efriis/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/efriis/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'assignees': [{'login': 'efriis',
#     'id': 9557659,
#     'node_id': 'MDQ6VXNlcjk1NTc2NTk=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/9557659?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/efriis',
#     'html_url': 'https://github.com/efriis',
#     'followers_url': 'https://api.github.com/users/efriis/followers',
#     'following_url': 'https://api.github.com/users/efriis/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/efriis/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/efriis/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/efriis/subscriptions',
#     'organizations_url': 'https://api.github.com/users/efriis/orgs',
#     'repos_url': 'https://api.github.com/users/efriis/repos',
#     'events_url': 'https://api.github.com/users/efriis/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/efriis/received_events',
#     'type': 'User',
#     'site_admin': False}],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2024-08-21T23:49:43Z',
#   'updated_at': '2024-08-22T02:25:47Z',
#   'closed_at': None,
#   'author_association': 'COLLABORATOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25646',
#    'html_url': 'https://github.com/langchain-ai/langchain/pull/25646',
#    'diff_url': 'https://github.com/langchain-ai/langchain/pull/25646.diff',
#    'patch_url': 'https://github.com/langchain-ai/langchain/pull/25646.patch',
#    'merged_at': None},
#   'body': "Updated titles into a consistent format. \r\nFixed links to the diagrams.\r\nFixed typos.\r\nNote: The Templates menu in the navbar is now sorted by the file names. I'll try sorting the navbar menus by the page titles, not the page file names.",
#   'reactions': {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25646/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25646/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25645',
#   'repository_url': 'https://api.github.com/repos/langchain-ai/langchain',
#   'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25645/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25645/comments',
#   'events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25645/events',
#   'html_url': 'https://github.com/langchain-ai/langchain/pull/25645',
#   'id': 2479421460,
#   'node_id': 'PR_kwDOIPDwls55Dpqj',
#   'number': 25645,
#   'title': 'core[patch]: support additional kwargs on StructuredPrompt',
#   'user': {'login': 'baskaryan',
#    'id': 22008038,
#    'node_id': 'MDQ6VXNlcjIyMDA4MDM4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22008038?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/baskaryan',
#    'html_url': 'https://github.com/baskaryan',
#    'followers_url': 'https://api.github.com/users/baskaryan/followers',
#    'following_url': 'https://api.github.com/users/baskaryan/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/baskaryan/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/baskaryan/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/baskaryan/subscriptions',
#    'organizations_url': 'https://api.github.com/users/baskaryan/orgs',
#    'repos_url': 'https://api.github.com/users/baskaryan/repos',
#    'events_url': 'https://api.github.com/users/baskaryan/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/baskaryan/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 5680700873,
#     'node_id': 'LA_kwDOIPDwls8AAAABUpidyQ',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%F0%9F%A4%96:improvement',
#     'name': '🤖:improvement',
#     'color': 'C5DEF5',
#     'default': False,
#     'description': 'Medium size change to existing code to handle new use-cases'},
#    {'id': 6232714126,
#     'node_id': 'LA_kwDOIPDwls8AAAABc3-rjg',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/size:L',
#     'name': 'size:L',
#     'color': 'F9D0C4',
#     'default': False,
#     'description': 'This PR changes 100-499 lines, ignoring generated files.'},
#    {'id': 6713033886,
#     'node_id': 'LA_kwDOIPDwls8AAAABkCDEng',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%E2%B1%AD:%20%20core',
#     'name': 'Ɑ:  core',
#     'color': 'D4C5F9',
#     'default': False,
#     'description': 'Related to langchain-core'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2024-08-21T23:32:29Z',
#   'updated_at': '2024-08-22T00:21:22Z',
#   'closed_at': None,
#   'author_association': 'COLLABORATOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25645',
#    'html_url': 'https://github.com/langchain-ai/langchain/pull/25645',
#    'diff_url': 'https://github.com/langchain-ai/langchain/pull/25645.diff',
#    'patch_url': 'https://github.com/langchain-ai/langchain/pull/25645.patch',
#    'merged_at': None},
#   'body': None,
#   'reactions': {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25645/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25645/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25644',
#   'repository_url': 'https://api.github.com/repos/langchain-ai/langchain',
#   'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25644/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25644/comments',
#   'events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25644/events',
#   'html_url': 'https://github.com/langchain-ai/langchain/pull/25644',
#   'id': 2479386224,
#   'node_id': 'PR_kwDOIPDwls55Dh_W',
#   'number': 25644,
#   'title': 'core+partners/anthropic: Anthropic prompt caching',
#   'user': {'login': 'mrdrprofuroboros',
#    'id': 21140507,
#    'node_id': 'MDQ6VXNlcjIxMTQwNTA3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/21140507?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mrdrprofuroboros',
#    'html_url': 'https://github.com/mrdrprofuroboros',
#    'followers_url': 'https://api.github.com/users/mrdrprofuroboros/followers',
#    'following_url': 'https://api.github.com/users/mrdrprofuroboros/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mrdrprofuroboros/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mrdrprofuroboros/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mrdrprofuroboros/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mrdrprofuroboros/orgs',
#    'repos_url': 'https://api.github.com/users/mrdrprofuroboros/repos',
#    'events_url': 'https://api.github.com/users/mrdrprofuroboros/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mrdrprofuroboros/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 5680700873,
#     'node_id': 'LA_kwDOIPDwls8AAAABUpidyQ',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%F0%9F%A4%96:improvement',
#     'name': '🤖:improvement',
#     'color': 'C5DEF5',
#     'default': False,
#     'description': 'Medium size change to existing code to handle new use-cases'},
#    {'id': 6232714126,
#     'node_id': 'LA_kwDOIPDwls8AAAABc3-rjg',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/size:L',
#     'name': 'size:L',
#     'color': 'F9D0C4',
#     'default': False,
#     'description': 'This PR changes 100-499 lines, ignoring generated files.'},
#    {'id': 6348691034,
#     'node_id': 'LA_kwDOIPDwls8AAAABemlWWg',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/partner',
#     'name': 'partner',
#     'color': 'ededed',
#     'default': False,
#     'description': None},
#    {'id': 6535251130,
#     'node_id': 'LA_kwDOIPDwls8AAAABhYgEug',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%F0%9F%94%8C:%20anthropic',
#     'name': '🔌: anthropic',
#     'color': 'BFD4F2',
#     'default': False,
#     'description': 'Primarily related to Anthropic integrations'},
#    {'id': 6713033886,
#     'node_id': 'LA_kwDOIPDwls8AAAABkCDEng',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%E2%B1%AD:%20%20core',
#     'name': 'Ɑ:  core',
#     'color': 'D4C5F9',
#     'default': False,
#     'description': 'Related to langchain-core'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': {'login': 'efriis',
#    'id': 9557659,
#    'node_id': 'MDQ6VXNlcjk1NTc2NTk=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/9557659?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/efriis',
#    'html_url': 'https://github.com/efriis',
#    'followers_url': 'https://api.github.com/users/efriis/followers',
#    'following_url': 'https://api.github.com/users/efriis/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/efriis/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/efriis/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/efriis/subscriptions',
#    'organizations_url': 'https://api.github.com/users/efriis/orgs',
#    'repos_url': 'https://api.github.com/users/efriis/repos',
#    'events_url': 'https://api.github.com/users/efriis/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/efriis/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'assignees': [{'login': 'efriis',
#     'id': 9557659,
#     'node_id': 'MDQ6VXNlcjk1NTc2NTk=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/9557659?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/efriis',
#     'html_url': 'https://github.com/efriis',
#     'followers_url': 'https://api.github.com/users/efriis/followers',
#     'following_url': 'https://api.github.com/users/efriis/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/efriis/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/efriis/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/efriis/subscriptions',
#     'organizations_url': 'https://api.github.com/users/efriis/orgs',
#     'repos_url': 'https://api.github.com/users/efriis/repos',
#     'events_url': 'https://api.github.com/users/efriis/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/efriis/received_events',
#     'type': 'User',
#     'site_admin': False}],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2024-08-21T22:50:53Z',
#   'updated_at': '2024-08-22T03:31:59Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25644',
#    'html_url': 'https://github.com/langchain-ai/langchain/pull/25644',
#    'diff_url': 'https://github.com/langchain-ai/langchain/pull/25644.diff',
#    'patch_url': 'https://github.com/langchain-ai/langchain/pull/25644.patch',
#    'merged_at': None},
#   'body': '**Description:** Added support for Anthropic prompt caching, see https://github.com/langchain-ai/langchain/discussions/25625\r\n**Issue:** the issue # it fixes, if applicable\r\n**Dependencies:** bump anthropic>=0.34.0\r\n\r\n* just found that it fails the test\r\nwill fix it and add usage example to the notebook, so far here:\r\n\r\n```python\r\nfrom langchain_anthropic import ChatAnthropic\r\nfrom langchain_core.messages import HumanMessage, SystemMessage\r\n\r\nmodel = ChatAnthropic(model="claude-3-5-sonnet-20240620", beta=True)\r\nmodel.invoke([\r\n    SystemMessage([{\r\n        "type": "text",\r\n        "text": "foo"*1000,\r\n        "cache_control": {"type": "ephemeral"}\r\n    }]),\r\n    HumanMessage("hi!"),\r\n])\r\n```\r\n\r\n```\r\nAIMessage(content=\'Hello! How can I assist you today?\', response_metadata={\'id\': \'msg_01XnYziv7oZtaRw23d45ivSi\', \'model\': \'claude-3-5-sonnet-20240620\', \'stop_reason\': \'end_turn\', \'stop_sequence\': None, \'usage\': {\'cache_creation_input_tokens\': 1500, \'cache_read_input_tokens\': 0, \'input_tokens\': 9, \'output_tokens\': 12}}, id=\'run-31a51a4f-bb0c-4b24-9c75-d7f7e5f99a89-0\', usage_metadata={\'input_tokens\': 9, \'output_tokens\': 12, \'total_tokens\': 21, \'cache_creation_input_tokens\': 1500, \'cache_read_input_tokens\': 0})\r\n```',
#   'reactions': {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25644/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25644/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25643',
#   'repository_url': 'https://api.github.com/repos/langchain-ai/langchain',
#   'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25643/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25643/comments',
#   'events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25643/events',
#   'html_url': 'https://github.com/langchain-ai/langchain/pull/25643',
#   'id': 2479143027,
#   'node_id': 'PR_kwDOIPDwls55Cy8M',
#   'number': 25643,
#   'title': '`community`: Updating default PPLX model to supported llama-3.1 model.',
#   'user': {'login': 'acompa',
#    'id': 272026,
#    'node_id': 'MDQ6VXNlcjI3MjAyNg==',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/272026?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/acompa',
#    'html_url': 'https://github.com/acompa',
#    'followers_url': 'https://api.github.com/users/acompa/followers',
#    'following_url': 'https://api.github.com/users/acompa/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/acompa/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/acompa/starred{/owner}{/repo}',
# ...
#   'reactions': {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25590/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25590/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25587',
#   'repository_url': 'https://api.github.com/repos/langchain-ai/langchain',
#   'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25587/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25587/comments',
#   'events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25587/events',
#   'html_url': 'https://github.com/langchain-ai/langchain/pull/25587',
#   'id': 2476198896,
#   'node_id': 'PR_kwDOIPDwls544zH0',
#   'number': 25587,
#   'title': 'docs[patch]: Hide and deindex template pages from in-docs search',
#   'user': {'login': 'jacoblee93',
#    'id': 6952323,
#    'node_id': 'MDQ6VXNlcjY5NTIzMjM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6952323?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jacoblee93',
#    'html_url': 'https://github.com/jacoblee93',
#    'followers_url': 'https://api.github.com/users/jacoblee93/followers',
#    'following_url': 'https://api.github.com/users/jacoblee93/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jacoblee93/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jacoblee93/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jacoblee93/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jacoblee93/orgs',
#    'repos_url': 'https://api.github.com/users/jacoblee93/repos',
#    'events_url': 'https://api.github.com/users/jacoblee93/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jacoblee93/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 5680700918,
#     'node_id': 'LA_kwDOIPDwls8AAAABUpid9g',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%F0%9F%A4%96:docs',
#     'name': '🤖:docs',
#     'color': 'C5DEF5',
#     'default': False,
#     'description': 'Changes to documentation and examples, like .md, .rst, .ipynb files. Changes to the docs/ folder'},
#    {'id': 6232714108,
#     'node_id': 'LA_kwDOIPDwls8AAAABc3-rfA',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/size:S',
#     'name': 'size:S',
#     'color': 'BFDADC',
#     'default': False,
#     'description': 'This PR changes 10-29 lines, ignoring generated files.'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2024-08-20T17:44:41Z',
#   'updated_at': '2024-08-20T17:59:49Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25587',
#    'html_url': 'https://github.com/langchain-ai/langchain/pull/25587',
#    'diff_url': 'https://github.com/langchain-ai/langchain/pull/25587.diff',
#    'patch_url': 'https://github.com/langchain-ai/langchain/pull/25587.patch',
#    'merged_at': None},
#   'body': 'Adds a new element to the bottom of these pages that I\'ll configure our docs search crawler to skip:\r\n\r\n```\r\n<span data-lc-docs-search-deindexed="true"></span>\r\n```',
#   'reactions': {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25587/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25587/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25583',
#   'repository_url': 'https://api.github.com/repos/langchain-ai/langchain',
#   'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25583/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25583/comments',
#   'events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25583/events',
#   'html_url': 'https://github.com/langchain-ai/langchain/pull/25583',
#   'id': 2476111245,
#   'node_id': 'PR_kwDOIPDwls544f9t',
#   'number': 25583,
#   'title': 'community: Refactor PebbloRetrievalQA',
#   'user': {'login': 'Raj725',
#    'id': 17705063,
#    'node_id': 'MDQ6VXNlcjE3NzA1MDYz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/17705063?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Raj725',
#    'html_url': 'https://github.com/Raj725',
#    'followers_url': 'https://api.github.com/users/Raj725/followers',
#    'following_url': 'https://api.github.com/users/Raj725/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Raj725/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Raj725/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Raj725/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Raj725/orgs',
#    'repos_url': 'https://api.github.com/users/Raj725/repos',
#    'events_url': 'https://api.github.com/users/Raj725/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Raj725/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 5680700892,
#     'node_id': 'LA_kwDOIPDwls8AAAABUpid3A',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%F0%9F%A4%96:refactor',
#     'name': '🤖:refactor',
#     'color': 'C5DEF5',
#     'default': False,
#     'description': 'A large refactor of a feature(s) or restructuring of many files'},
#    {'id': 6232714130,
#     'node_id': 'LA_kwDOIPDwls8AAAABc3-rkg',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/size:XL',
#     'name': 'size:XL',
#     'color': 'E99695',
#     'default': False,
#     'description': 'This PR changes 500-999 lines, ignoring generated files.'},
#    {'id': 7097373342,
#     'node_id': 'LA_kwDOIPDwls8AAAABpwlSng',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/community',
#     'name': 'community',
#     'color': '579082',
#     'default': False,
#     'description': 'Related to langchain-community'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2024-08-20T16:51:38Z',
#   'updated_at': '2024-08-22T03:44:17Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25583',
#    'html_url': 'https://github.com/langchain-ai/langchain/pull/25583',
#    'diff_url': 'https://github.com/langchain-ai/langchain/pull/25583.diff',
#    'patch_url': 'https://github.com/langchain-ai/langchain/pull/25583.patch',
#    'merged_at': None},
#   'body': '**Refactor PebbloRetrievalQA**\r\n  - Created `APIWrapper` and moved API logic into it.\r\n  - Created smaller functions/methods for better readability.\r\n  - Properly read environment variables.\r\n  - Removed unused code.\r\n  - Updated models\r\n\r\n**Issue:** NA\r\n**Dependencies:** NA\r\n**tests**:  NA\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25583/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25583/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25582',
#   'repository_url': 'https://api.github.com/repos/langchain-ai/langchain',
#   'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25582/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25582/comments',
#   'events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25582/events',
#   'html_url': 'https://github.com/langchain-ai/langchain/pull/25582',
#   'id': 2476109964,
#   'node_id': 'PR_kwDOIPDwls544fru',
#   'number': 25582,
#   'title': 'community: Refactor PebbloSafeLoader',
#   'user': {'login': 'Raj725',
#    'id': 17705063,
#    'node_id': 'MDQ6VXNlcjE3NzA1MDYz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/17705063?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Raj725',
#    'html_url': 'https://github.com/Raj725',
#    'followers_url': 'https://api.github.com/users/Raj725/followers',
#    'following_url': 'https://api.github.com/users/Raj725/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Raj725/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Raj725/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Raj725/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Raj725/orgs',
#    'repos_url': 'https://api.github.com/users/Raj725/repos',
#    'events_url': 'https://api.github.com/users/Raj725/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Raj725/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 5541144676,
#     'node_id': 'LA_kwDOIPDwls8AAAABSkcoZA',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%E2%B1%AD:%20doc%20loader',
#     'name': 'Ɑ: doc loader',
#     'color': 'D4C5F9',
#     'default': False,
#     'description': 'Related to document loader module (not documentation)'},
#    {'id': 5680700892,
#     'node_id': 'LA_kwDOIPDwls8AAAABUpid3A',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%F0%9F%A4%96:refactor',
#     'name': '🤖:refactor',
#     'color': 'C5DEF5',
#     'default': False,
#     'description': 'A large refactor of a feature(s) or restructuring of many files'},
#    {'id': 6232714130,
#     'node_id': 'LA_kwDOIPDwls8AAAABc3-rkg',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/size:XL',
#     'name': 'size:XL',
#     'color': 'E99695',
#     'default': False,
#     'description': 'This PR changes 500-999 lines, ignoring generated files.'},
#    {'id': 7097373342,
#     'node_id': 'LA_kwDOIPDwls8AAAABpwlSng',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/community',
#     'name': 'community',
#     'color': '579082',
#     'default': False,
#     'description': 'Related to langchain-community'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2024-08-20T16:50:52Z',
#   'updated_at': '2024-08-22T03:43:37Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25582',
#    'html_url': 'https://github.com/langchain-ai/langchain/pull/25582',
#    'diff_url': 'https://github.com/langchain-ai/langchain/pull/25582.diff',
#    'patch_url': 'https://github.com/langchain-ai/langchain/pull/25582.patch',
#    'merged_at': None},
#   'body': '**Refactor PebbloSafeLoader**\r\n  - Created `APIWrapper` and moved API logic into it.\r\n  - Moved helper functions to the utility file.\r\n  - Created smaller functions and methods for better readability.\r\n  - Properly read environment variables.\r\n  - Removed unused code.\r\n\r\n**Issue:** NA\r\n**Dependencies:** NA\r\n**tests**:  Updated\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25582/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25582/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25581',
#   'repository_url': 'https://api.github.com/repos/langchain-ai/langchain',
#   'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25581/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25581/comments',
#   'events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25581/events',
#   'html_url': 'https://github.com/langchain-ai/langchain/pull/25581',
#   'id': 2476026212,
#   'node_id': 'PR_kwDOIPDwls544Nxd',
#   'number': 25581,
#   'title': 'core: support drawing nested subgraphs in draw_mermaid',
#   'user': {'login': 'vbarda',
#    'id': 19161700,
#    'node_id': 'MDQ6VXNlcjE5MTYxNzAw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19161700?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/vbarda',
#    'html_url': 'https://github.com/vbarda',
#    'followers_url': 'https://api.github.com/users/vbarda/followers',
#    'following_url': 'https://api.github.com/users/vbarda/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/vbarda/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/vbarda/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/vbarda/subscriptions',
#    'organizations_url': 'https://api.github.com/users/vbarda/orgs',
#    'repos_url': 'https://api.github.com/users/vbarda/repos',
#    'events_url': 'https://api.github.com/users/vbarda/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/vbarda/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 5680700873,
#     'node_id': 'LA_kwDOIPDwls8AAAABUpidyQ',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%F0%9F%A4%96:improvement',
#     'name': '🤖:improvement',
#     'color': 'C5DEF5',
#     'default': False,
#     'description': 'Medium size change to existing code to handle new use-cases'},
#    {'id': 6232714126,
#     'node_id': 'LA_kwDOIPDwls8AAAABc3-rjg',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/size:L',
#     'name': 'size:L',
#     'color': 'F9D0C4',
#     'default': False,
#     'description': 'This PR changes 100-499 lines, ignoring generated files.'},
#    {'id': 6713033886,
#     'node_id': 'LA_kwDOIPDwls8AAAABkCDEng',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%E2%B1%AD:%20%20core',
#     'name': 'Ɑ:  core',
#     'color': 'D4C5F9',
#     'default': False,
#     'description': 'Related to langchain-core'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2024-08-20T16:08:10Z',
#   'updated_at': '2024-08-21T14:15:39Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25581',
#    'html_url': 'https://github.com/langchain-ai/langchain/pull/25581',
#    'diff_url': 'https://github.com/langchain-ai/langchain/pull/25581.diff',
#    'patch_url': 'https://github.com/langchain-ai/langchain/pull/25581.patch',
#    'merged_at': None},
#   'body': 'Previously the code was able to only handle a single level of nesting for subgraphs in mermaid. This change adds support for arbitrary nesting of subgraphs.',
#   'reactions': {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25581/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25581/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None}]

# %% [markdown]
# ### List Pull Requests API
#
# API完整文档说明见：https://docs.github.com/en/rest/pulls/pulls?apiVersion=2022-11-28#list-pull-requests
#
# **请求样例**：`GET /repos/{owner}/{repo}/pulls`;

# %%
pull_requests = github_client.fetch_pull_requests(repo)

# %%
pull_requests
# Out:
# [{'url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25652',
#   'id': 2031227004,
#   'node_id': 'PR_kwDOIPDwls55EhB8',
#   'html_url': 'https://github.com/langchain-ai/langchain/pull/25652',
#   'diff_url': 'https://github.com/langchain-ai/langchain/pull/25652.diff',
#   'patch_url': 'https://github.com/langchain-ai/langchain/pull/25652.patch',
#   'issue_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25652',
#   'number': 25652,
#   'state': 'open',
#   'locked': False,
#   'title': '[community] Support passing extra params for executing functions in UCFunctionToolkit',
#   'user': {'login': 'serena-ruan',
#    'id': 82044803,
#    'node_id': 'MDQ6VXNlcjgyMDQ0ODAz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/82044803?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/serena-ruan',
#    'html_url': 'https://github.com/serena-ruan',
#    'followers_url': 'https://api.github.com/users/serena-ruan/followers',
#    'following_url': 'https://api.github.com/users/serena-ruan/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/serena-ruan/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/serena-ruan/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/serena-ruan/subscriptions',
#    'organizations_url': 'https://api.github.com/users/serena-ruan/orgs',
#    'repos_url': 'https://api.github.com/users/serena-ruan/repos',
#    'events_url': 'https://api.github.com/users/serena-ruan/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/serena-ruan/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'body': 'Thank you for contributing to LangChain!\r\n\r\n- [x] **PR title**: "package: description"\r\n  - Where "package" is whichever of langchain, community, core, experimental, etc. is being modified. Use "docs: ..." for purely docs changes, "templates: ..." for template changes, "infra: ..." for CI changes.\r\n  - Example: "community: add foobar LLM"\r\n\r\n\r\nSupport passing extra params when executing UC functions:\r\nThe params should be a dictionary with key EXECUTE_FUNCTION_ARG_NAME, the assumption is that the function itself doesn\'t use such variable name (starting and ending with double underscores), and if it does we raise Exception.\r\nIf invalid params passing to the execute_statement, we raise Exception as well.\r\n\r\n\r\n- [x] **Add tests and docs**: If you\'re adding a new integration, please include\r\n  1. a test for the integration, preferably unit tests that do not rely on network access,\r\n  2. an example notebook showing its use. It lives in `docs/docs/integrations` directory.\r\n\r\n\r\n- [x] **Lint and test**: Run `make format`, `make lint` and `make test` from the root of the package(s) you\'ve modified. See contribution guidelines for more: https://python.langchain.com/docs/contributing/\r\n\r\nAdditional guidelines:\r\n- Make sure optional dependencies are imported within a function.\r\n- Please do not add dependencies to pyproject.toml files (even optional ones) unless they are required for unit tests.\r\n- Most PRs should not touch more than one package.\r\n- Changes should be backwards compatible.\r\n- If you are adding something to community, do not re-import it in langchain.\r\n\r\nIf no one reviews your PR within a few days, please @-mention one of baskaryan, efriis, eyurtsev, ccurme, vbarda, hwchase17.\r\n',
#   'created_at': '2024-08-22T04:06:47Z',
#   'updated_at': '2024-08-22T04:07:32Z',
#   'closed_at': None,
#   'merged_at': None,
#   'merge_commit_sha': 'd44a10b26f11e8b4ec96bf171a7955eb2ca36309',
#   'assignee': None,
#   'assignees': [],
#   'requested_reviewers': [],
#   'requested_teams': [],
#   'labels': [{'id': 5680700873,
#     'node_id': 'LA_kwDOIPDwls8AAAABUpidyQ',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%F0%9F%A4%96:improvement',
#     'name': '🤖:improvement',
#     'color': 'C5DEF5',
#     'default': False,
#     'description': 'Medium size change to existing code to handle new use-cases'},
#    {'id': 6232714126,
#     'node_id': 'LA_kwDOIPDwls8AAAABc3-rjg',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/size:L',
#     'name': 'size:L',
#     'color': 'F9D0C4',
#     'default': False,
#     'description': 'This PR changes 100-499 lines, ignoring generated files.'},
#    {'id': 7097373342,
#     'node_id': 'LA_kwDOIPDwls8AAAABpwlSng',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/community',
#     'name': 'community',
#     'color': '579082',
#     'default': False,
#     'description': 'Related to langchain-community'}],
#   'milestone': None,
#   'draft': False,
#   'commits_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25652/commits',
#   'review_comments_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25652/comments',
#   'review_comment_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/comments{/number}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25652/comments',
#   'statuses_url': 'https://api.github.com/repos/langchain-ai/langchain/statuses/796f1fe23ea06c7684e65a848e9959253423c11c',
#   'head': {'label': 'serena-ruan:tool',
#    'ref': 'tool',
#    'sha': '796f1fe23ea06c7684e65a848e9959253423c11c',
#    'user': {'login': 'serena-ruan',
#     'id': 82044803,
#     'node_id': 'MDQ6VXNlcjgyMDQ0ODAz',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/82044803?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/serena-ruan',
#     'html_url': 'https://github.com/serena-ruan',
#     'followers_url': 'https://api.github.com/users/serena-ruan/followers',
#     'following_url': 'https://api.github.com/users/serena-ruan/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/serena-ruan/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/serena-ruan/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/serena-ruan/subscriptions',
#     'organizations_url': 'https://api.github.com/users/serena-ruan/orgs',
#     'repos_url': 'https://api.github.com/users/serena-ruan/repos',
#     'events_url': 'https://api.github.com/users/serena-ruan/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/serena-ruan/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'repo': {'id': 722844865,
#     'node_id': 'R_kgDOKxW8wQ',
#     'name': 'langchain',
#     'full_name': 'serena-ruan/langchain',
#     'private': False,
#     'owner': {'login': 'serena-ruan',
#      'id': 82044803,
#      'node_id': 'MDQ6VXNlcjgyMDQ0ODAz',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/82044803?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/serena-ruan',
#      'html_url': 'https://github.com/serena-ruan',
#      'followers_url': 'https://api.github.com/users/serena-ruan/followers',
#      'following_url': 'https://api.github.com/users/serena-ruan/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/serena-ruan/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/serena-ruan/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/serena-ruan/subscriptions',
#      'organizations_url': 'https://api.github.com/users/serena-ruan/orgs',
#      'repos_url': 'https://api.github.com/users/serena-ruan/repos',
#      'events_url': 'https://api.github.com/users/serena-ruan/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/serena-ruan/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/serena-ruan/langchain',
#     'description': '⚡ Building applications with LLMs through composability ⚡',
#     'fork': True,
#     'url': 'https://api.github.com/repos/serena-ruan/langchain',
#     'forks_url': 'https://api.github.com/repos/serena-ruan/langchain/forks',
#     'keys_url': 'https://api.github.com/repos/serena-ruan/langchain/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/serena-ruan/langchain/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/serena-ruan/langchain/teams',
#     'hooks_url': 'https://api.github.com/repos/serena-ruan/langchain/hooks',
#     'issue_events_url': 'https://api.github.com/repos/serena-ruan/langchain/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/serena-ruan/langchain/events',
#     'assignees_url': 'https://api.github.com/repos/serena-ruan/langchain/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/serena-ruan/langchain/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/serena-ruan/langchain/tags',
#     'blobs_url': 'https://api.github.com/repos/serena-ruan/langchain/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/serena-ruan/langchain/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/serena-ruan/langchain/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/serena-ruan/langchain/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/serena-ruan/langchain/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/serena-ruan/langchain/languages',
#     'stargazers_url': 'https://api.github.com/repos/serena-ruan/langchain/stargazers',
#     'contributors_url': 'https://api.github.com/repos/serena-ruan/langchain/contributors',
#     'subscribers_url': 'https://api.github.com/repos/serena-ruan/langchain/subscribers',
#     'subscription_url': 'https://api.github.com/repos/serena-ruan/langchain/subscription',
#     'commits_url': 'https://api.github.com/repos/serena-ruan/langchain/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/serena-ruan/langchain/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/serena-ruan/langchain/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/serena-ruan/langchain/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/serena-ruan/langchain/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/serena-ruan/langchain/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/serena-ruan/langchain/merges',
#     'archive_url': 'https://api.github.com/repos/serena-ruan/langchain/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/serena-ruan/langchain/downloads',
#     'issues_url': 'https://api.github.com/repos/serena-ruan/langchain/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/serena-ruan/langchain/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/serena-ruan/langchain/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/serena-ruan/langchain/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/serena-ruan/langchain/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/serena-ruan/langchain/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/serena-ruan/langchain/deployments',
#     'created_at': '2023-11-24T04:57:45Z',
#     'updated_at': '2023-11-24T04:57:45Z',
#     'pushed_at': '2024-08-22T04:07:05Z',
#     'git_url': 'git://github.com/serena-ruan/langchain.git',
#     'ssh_url': 'git@github.com:serena-ruan/langchain.git',
#     'clone_url': 'https://github.com/serena-ruan/langchain.git',
#     'svn_url': 'https://github.com/serena-ruan/langchain',
#     'homepage': 'https://python.langchain.com',
#     'size': 171069,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'has_discussions': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': {'key': 'mit',
#      'name': 'MIT License',
#      'spdx_id': 'MIT',
#      'url': 'https://api.github.com/licenses/mit',
#      'node_id': 'MDc6TGljZW5zZTEz'},
#     'allow_forking': True,
#     'is_template': False,
#     'web_commit_signoff_required': False,
#     'topics': [],
#     'visibility': 'public',
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'master'}},
#   'base': {'label': 'langchain-ai:master',
#    'ref': 'master',
#    'sha': '3981d736df7b113346670f4e26cb8ee0ecaa656e',
#    'user': {'login': 'langchain-ai',
#     'id': 126733545,
#     'node_id': 'O_kgDOB43M6Q',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/126733545?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/langchain-ai',
#     'html_url': 'https://github.com/langchain-ai',
#     'followers_url': 'https://api.github.com/users/langchain-ai/followers',
#     'following_url': 'https://api.github.com/users/langchain-ai/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/langchain-ai/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/langchain-ai/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/langchain-ai/subscriptions',
#     'organizations_url': 'https://api.github.com/users/langchain-ai/orgs',
#     'repos_url': 'https://api.github.com/users/langchain-ai/repos',
#     'events_url': 'https://api.github.com/users/langchain-ai/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/langchain-ai/received_events',
#     'type': 'Organization',
#     'site_admin': False},
#    'repo': {'id': 552661142,
#     'node_id': 'R_kgDOIPDwlg',
#     'name': 'langchain',
#     'full_name': 'langchain-ai/langchain',
#     'private': False,
#     'owner': {'login': 'langchain-ai',
#      'id': 126733545,
#      'node_id': 'O_kgDOB43M6Q',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/126733545?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/langchain-ai',
#      'html_url': 'https://github.com/langchain-ai',
#      'followers_url': 'https://api.github.com/users/langchain-ai/followers',
#      'following_url': 'https://api.github.com/users/langchain-ai/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/langchain-ai/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/langchain-ai/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/langchain-ai/subscriptions',
#      'organizations_url': 'https://api.github.com/users/langchain-ai/orgs',
#      'repos_url': 'https://api.github.com/users/langchain-ai/repos',
#      'events_url': 'https://api.github.com/users/langchain-ai/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/langchain-ai/received_events',
#      'type': 'Organization',
#      'site_admin': False},
#     'html_url': 'https://github.com/langchain-ai/langchain',
#     'description': '🦜🔗 Build context-aware reasoning applications',
#     'fork': False,
#     'url': 'https://api.github.com/repos/langchain-ai/langchain',
#     'forks_url': 'https://api.github.com/repos/langchain-ai/langchain/forks',
#     'keys_url': 'https://api.github.com/repos/langchain-ai/langchain/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/langchain-ai/langchain/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/langchain-ai/langchain/teams',
#     'hooks_url': 'https://api.github.com/repos/langchain-ai/langchain/hooks',
#     'issue_events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/langchain-ai/langchain/events',
#     'assignees_url': 'https://api.github.com/repos/langchain-ai/langchain/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/langchain-ai/langchain/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/langchain-ai/langchain/tags',
#     'blobs_url': 'https://api.github.com/repos/langchain-ai/langchain/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/langchain-ai/langchain/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/langchain-ai/langchain/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/langchain-ai/langchain/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/langchain-ai/langchain/languages',
#     'stargazers_url': 'https://api.github.com/repos/langchain-ai/langchain/stargazers',
#     'contributors_url': 'https://api.github.com/repos/langchain-ai/langchain/contributors',
#     'subscribers_url': 'https://api.github.com/repos/langchain-ai/langchain/subscribers',
#     'subscription_url': 'https://api.github.com/repos/langchain-ai/langchain/subscription',
#     'commits_url': 'https://api.github.com/repos/langchain-ai/langchain/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/langchain-ai/langchain/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/langchain-ai/langchain/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/langchain-ai/langchain/merges',
#     'archive_url': 'https://api.github.com/repos/langchain-ai/langchain/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/langchain-ai/langchain/downloads',
#     'issues_url': 'https://api.github.com/repos/langchain-ai/langchain/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/langchain-ai/langchain/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/langchain-ai/langchain/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/langchain-ai/langchain/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/langchain-ai/langchain/deployments',
#     'created_at': '2022-10-17T02:58:36Z',
#     'updated_at': '2024-08-22T03:49:13Z',
#     'pushed_at': '2024-08-22T04:12:00Z',
#     'git_url': 'git://github.com/langchain-ai/langchain.git',
#     'ssh_url': 'git@github.com:langchain-ai/langchain.git',
#     'clone_url': 'https://github.com/langchain-ai/langchain.git',
#     'svn_url': 'https://github.com/langchain-ai/langchain',
#     'homepage': 'https://python.langchain.com',
#     'size': 290611,
#     'stargazers_count': 91030,
#     'watchers_count': 91030,
#     'language': 'Jupyter Notebook',
#     'has_issues': True,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'has_discussions': True,
#     'forks_count': 14469,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 1011,
#     'license': {'key': 'mit',
#      'name': 'MIT License',
#      'spdx_id': 'MIT',
#      'url': 'https://api.github.com/licenses/mit',
#      'node_id': 'MDc6TGljZW5zZTEz'},
#     'allow_forking': True,
#     'is_template': False,
#     'web_commit_signoff_required': False,
#     'topics': [],
#     'visibility': 'public',
#     'forks': 14469,
#     'open_issues': 1011,
#     'watchers': 91030,
#     'default_branch': 'master'}},
#   '_links': {'self': {'href': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25652'},
#    'html': {'href': 'https://github.com/langchain-ai/langchain/pull/25652'},
#    'issue': {'href': 'https://api.github.com/repos/langchain-ai/langchain/issues/25652'},
#    'comments': {'href': 'https://api.github.com/repos/langchain-ai/langchain/issues/25652/comments'},
#    'review_comments': {'href': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25652/comments'},
#    'review_comment': {'href': 'https://api.github.com/repos/langchain-ai/langchain/pulls/comments{/number}'},
#    'commits': {'href': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25652/commits'},
#    'statuses': {'href': 'https://api.github.com/repos/langchain-ai/langchain/statuses/796f1fe23ea06c7684e65a848e9959253423c11c'}},
#   'author_association': 'CONTRIBUTOR',
#   'auto_merge': None,
#   'active_lock_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25650',
#   'id': 2031199463,
#   'node_id': 'PR_kwDOIPDwls55EaTn',
#   'html_url': 'https://github.com/langchain-ai/langchain/pull/25650',
#   'diff_url': 'https://github.com/langchain-ai/langchain/pull/25650.diff',
#   'patch_url': 'https://github.com/langchain-ai/langchain/pull/25650.patch',
#   'issue_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25650',
#   'number': 25650,
#   'state': 'open',
#   'locked': False,
#   'title': 'docs: sorted Templates menu',
#   'user': {'login': 'leo-gan',
#    'id': 2256422,
#    'node_id': 'MDQ6VXNlcjIyNTY0MjI=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2256422?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/leo-gan',
#    'html_url': 'https://github.com/leo-gan',
#    'followers_url': 'https://api.github.com/users/leo-gan/followers',
#    'following_url': 'https://api.github.com/users/leo-gan/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/leo-gan/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/leo-gan/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/leo-gan/subscriptions',
#    'organizations_url': 'https://api.github.com/users/leo-gan/orgs',
#    'repos_url': 'https://api.github.com/users/leo-gan/repos',
#    'events_url': 'https://api.github.com/users/leo-gan/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/leo-gan/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'body': 'The Templates menu is sorted by the file names.\r\nI want to sort in by the Titles (where Title is a line, started with "# " (H1)).',
#   'created_at': '2024-08-22T03:29:26Z',
#   'updated_at': '2024-08-22T03:35:07Z',
#   'closed_at': None,
#   'merged_at': None,
#   'merge_commit_sha': '09ff740ae049f8f2beeedd0f2c3084f4177b8dff',
#   'assignee': None,
#   'assignees': [],
#   'requested_reviewers': [],
#   'requested_teams': [],
#   'labels': [],
#   'milestone': None,
#   'draft': True,
#   'commits_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25650/commits',
#   'review_comments_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25650/comments',
#   'review_comment_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/comments{/number}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25650/comments',
#   'statuses_url': 'https://api.github.com/repos/langchain-ai/langchain/statuses/b6e4cd3f46712443a6c9310fc4fd4296eae95634',
#   'head': {'label': 'leo-gan:docs-templates-menu-sorting',
#    'ref': 'docs-templates-menu-sorting',
#    'sha': 'b6e4cd3f46712443a6c9310fc4fd4296eae95634',
#    'user': {'login': 'leo-gan',
#     'id': 2256422,
#     'node_id': 'MDQ6VXNlcjIyNTY0MjI=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/2256422?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/leo-gan',
#     'html_url': 'https://github.com/leo-gan',
#     'followers_url': 'https://api.github.com/users/leo-gan/followers',
#     'following_url': 'https://api.github.com/users/leo-gan/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/leo-gan/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/leo-gan/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/leo-gan/subscriptions',
#     'organizations_url': 'https://api.github.com/users/leo-gan/orgs',
#     'repos_url': 'https://api.github.com/users/leo-gan/repos',
#     'events_url': 'https://api.github.com/users/leo-gan/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/leo-gan/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'repo': {'id': 703236496,
#     'node_id': 'R_kgDOKeqJkA',
#     'name': 'langchain',
#     'full_name': 'leo-gan/langchain',
#     'private': False,
#     'owner': {'login': 'leo-gan',
#      'id': 2256422,
#      'node_id': 'MDQ6VXNlcjIyNTY0MjI=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/2256422?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/leo-gan',
#      'html_url': 'https://github.com/leo-gan',
#      'followers_url': 'https://api.github.com/users/leo-gan/followers',
#      'following_url': 'https://api.github.com/users/leo-gan/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/leo-gan/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/leo-gan/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/leo-gan/subscriptions',
#      'organizations_url': 'https://api.github.com/users/leo-gan/orgs',
#      'repos_url': 'https://api.github.com/users/leo-gan/repos',
#      'events_url': 'https://api.github.com/users/leo-gan/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/leo-gan/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/leo-gan/langchain',
#     'description': '⚡ Building applications with LLMs through composability ⚡',
#     'fork': True,
#     'url': 'https://api.github.com/repos/leo-gan/langchain',
#     'forks_url': 'https://api.github.com/repos/leo-gan/langchain/forks',
#     'keys_url': 'https://api.github.com/repos/leo-gan/langchain/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/leo-gan/langchain/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/leo-gan/langchain/teams',
#     'hooks_url': 'https://api.github.com/repos/leo-gan/langchain/hooks',
#     'issue_events_url': 'https://api.github.com/repos/leo-gan/langchain/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/leo-gan/langchain/events',
#     'assignees_url': 'https://api.github.com/repos/leo-gan/langchain/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/leo-gan/langchain/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/leo-gan/langchain/tags',
#     'blobs_url': 'https://api.github.com/repos/leo-gan/langchain/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/leo-gan/langchain/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/leo-gan/langchain/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/leo-gan/langchain/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/leo-gan/langchain/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/leo-gan/langchain/languages',
#     'stargazers_url': 'https://api.github.com/repos/leo-gan/langchain/stargazers',
#     'contributors_url': 'https://api.github.com/repos/leo-gan/langchain/contributors',
#     'subscribers_url': 'https://api.github.com/repos/leo-gan/langchain/subscribers',
#     'subscription_url': 'https://api.github.com/repos/leo-gan/langchain/subscription',
#     'commits_url': 'https://api.github.com/repos/leo-gan/langchain/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/leo-gan/langchain/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/leo-gan/langchain/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/leo-gan/langchain/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/leo-gan/langchain/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/leo-gan/langchain/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/leo-gan/langchain/merges',
#     'archive_url': 'https://api.github.com/repos/leo-gan/langchain/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/leo-gan/langchain/downloads',
#     'issues_url': 'https://api.github.com/repos/leo-gan/langchain/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/leo-gan/langchain/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/leo-gan/langchain/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/leo-gan/langchain/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/leo-gan/langchain/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/leo-gan/langchain/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/leo-gan/langchain/deployments',
#     'created_at': '2023-10-10T21:24:36Z',
#     'updated_at': '2024-08-21T20:42:46Z',
#     'pushed_at': '2024-08-22T03:27:26Z',
#     'git_url': 'git://github.com/leo-gan/langchain.git',
#     'ssh_url': 'git@github.com:leo-gan/langchain.git',
#     'clone_url': 'https://github.com/leo-gan/langchain.git',
#     'svn_url': 'https://github.com/leo-gan/langchain',
#     'homepage': 'https://python.langchain.com',
#     'size': 238320,
#     'stargazers_count': 1,
#     'watchers_count': 1,
#     'language': 'Jupyter Notebook',
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'has_discussions': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': {'key': 'mit',
#      'name': 'MIT License',
#      'spdx_id': 'MIT',
#      'url': 'https://api.github.com/licenses/mit',
#      'node_id': 'MDc6TGljZW5zZTEz'},
#     'allow_forking': True,
#     'is_template': False,
#     'web_commit_signoff_required': False,
#     'topics': [],
#     'visibility': 'public',
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 1,
#     'default_branch': 'master'}},
#   'base': {'label': 'langchain-ai:master',
#    'ref': 'master',
#    'sha': '3981d736df7b113346670f4e26cb8ee0ecaa656e',
#    'user': {'login': 'langchain-ai',
#     'id': 126733545,
#     'node_id': 'O_kgDOB43M6Q',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/126733545?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/langchain-ai',
#     'html_url': 'https://github.com/langchain-ai',
#     'followers_url': 'https://api.github.com/users/langchain-ai/followers',
#     'following_url': 'https://api.github.com/users/langchain-ai/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/langchain-ai/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/langchain-ai/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/langchain-ai/subscriptions',
#     'organizations_url': 'https://api.github.com/users/langchain-ai/orgs',
#     'repos_url': 'https://api.github.com/users/langchain-ai/repos',
#     'events_url': 'https://api.github.com/users/langchain-ai/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/langchain-ai/received_events',
#     'type': 'Organization',
#     'site_admin': False},
#    'repo': {'id': 552661142,
#     'node_id': 'R_kgDOIPDwlg',
#     'name': 'langchain',
#     'full_name': 'langchain-ai/langchain',
#     'private': False,
#     'owner': {'login': 'langchain-ai',
#      'id': 126733545,
#      'node_id': 'O_kgDOB43M6Q',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/126733545?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/langchain-ai',
#      'html_url': 'https://github.com/langchain-ai',
#      'followers_url': 'https://api.github.com/users/langchain-ai/followers',
#      'following_url': 'https://api.github.com/users/langchain-ai/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/langchain-ai/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/langchain-ai/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/langchain-ai/subscriptions',
#      'organizations_url': 'https://api.github.com/users/langchain-ai/orgs',
#      'repos_url': 'https://api.github.com/users/langchain-ai/repos',
#      'events_url': 'https://api.github.com/users/langchain-ai/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/langchain-ai/received_events',
#      'type': 'Organization',
#      'site_admin': False},
#     'html_url': 'https://github.com/langchain-ai/langchain',
#     'description': '🦜🔗 Build context-aware reasoning applications',
#     'fork': False,
#     'url': 'https://api.github.com/repos/langchain-ai/langchain',
#     'forks_url': 'https://api.github.com/repos/langchain-ai/langchain/forks',
#     'keys_url': 'https://api.github.com/repos/langchain-ai/langchain/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/langchain-ai/langchain/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/langchain-ai/langchain/teams',
#     'hooks_url': 'https://api.github.com/repos/langchain-ai/langchain/hooks',
#     'issue_events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/langchain-ai/langchain/events',
#     'assignees_url': 'https://api.github.com/repos/langchain-ai/langchain/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/langchain-ai/langchain/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/langchain-ai/langchain/tags',
#     'blobs_url': 'https://api.github.com/repos/langchain-ai/langchain/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/langchain-ai/langchain/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/langchain-ai/langchain/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/langchain-ai/langchain/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/langchain-ai/langchain/languages',
#     'stargazers_url': 'https://api.github.com/repos/langchain-ai/langchain/stargazers',
#     'contributors_url': 'https://api.github.com/repos/langchain-ai/langchain/contributors',
#     'subscribers_url': 'https://api.github.com/repos/langchain-ai/langchain/subscribers',
#     'subscription_url': 'https://api.github.com/repos/langchain-ai/langchain/subscription',
#     'commits_url': 'https://api.github.com/repos/langchain-ai/langchain/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/langchain-ai/langchain/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/langchain-ai/langchain/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/langchain-ai/langchain/merges',
#     'archive_url': 'https://api.github.com/repos/langchain-ai/langchain/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/langchain-ai/langchain/downloads',
#     'issues_url': 'https://api.github.com/repos/langchain-ai/langchain/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/langchain-ai/langchain/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/langchain-ai/langchain/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/langchain-ai/langchain/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/langchain-ai/langchain/deployments',
#     'created_at': '2022-10-17T02:58:36Z',
#     'updated_at': '2024-08-22T03:49:13Z',
#     'pushed_at': '2024-08-22T04:12:00Z',
#     'git_url': 'git://github.com/langchain-ai/langchain.git',
#     'ssh_url': 'git@github.com:langchain-ai/langchain.git',
#     'clone_url': 'https://github.com/langchain-ai/langchain.git',
#     'svn_url': 'https://github.com/langchain-ai/langchain',
#     'homepage': 'https://python.langchain.com',
#     'size': 290611,
#     'stargazers_count': 91030,
#     'watchers_count': 91030,
#     'language': 'Jupyter Notebook',
#     'has_issues': True,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'has_discussions': True,
#     'forks_count': 14469,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 1011,
#     'license': {'key': 'mit',
#      'name': 'MIT License',
#      'spdx_id': 'MIT',
#      'url': 'https://api.github.com/licenses/mit',
#      'node_id': 'MDc6TGljZW5zZTEz'},
#     'allow_forking': True,
#     'is_template': False,
#     'web_commit_signoff_required': False,
#     'topics': [],
#     'visibility': 'public',
#     'forks': 14469,
#     'open_issues': 1011,
#     'watchers': 91030,
#     'default_branch': 'master'}},
#   '_links': {'self': {'href': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25650'},
#    'html': {'href': 'https://github.com/langchain-ai/langchain/pull/25650'},
#    'issue': {'href': 'https://api.github.com/repos/langchain-ai/langchain/issues/25650'},
#    'comments': {'href': 'https://api.github.com/repos/langchain-ai/langchain/issues/25650/comments'},
#    'review_comments': {'href': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25650/comments'},
#    'review_comment': {'href': 'https://api.github.com/repos/langchain-ai/langchain/pulls/comments{/number}'},
#    'commits': {'href': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25650/commits'},
#    'statuses': {'href': 'https://api.github.com/repos/langchain-ai/langchain/statuses/b6e4cd3f46712443a6c9310fc4fd4296eae95634'}},
#   'author_association': 'COLLABORATOR',
#   'auto_merge': None,
#   'active_lock_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25649',
#   'id': 2031060988,
#   'node_id': 'PR_kwDOIPDwls55D4f8',
#   'html_url': 'https://github.com/langchain-ai/langchain/pull/25649',
#   'diff_url': 'https://github.com/langchain-ai/langchain/pull/25649.diff',
#   'patch_url': 'https://github.com/langchain-ai/langchain/pull/25649.patch',
#   'issue_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25649',
#   'number': 25649,
#   'state': 'open',
#   'locked': False,
#   'title': 'docs: Change Pull Request to Merge Request in GitLab notebook',
#   'user': {'login': 'DylanGriffith',
#    'id': 1002737,
#    'node_id': 'MDQ6VXNlcjEwMDI3Mzc=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1002737?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/DylanGriffith',
#    'html_url': 'https://github.com/DylanGriffith',
#    'followers_url': 'https://api.github.com/users/DylanGriffith/followers',
#    'following_url': 'https://api.github.com/users/DylanGriffith/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/DylanGriffith/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/DylanGriffith/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/DylanGriffith/subscriptions',
#    'organizations_url': 'https://api.github.com/users/DylanGriffith/orgs',
#    'repos_url': 'https://api.github.com/users/DylanGriffith/repos',
#    'events_url': 'https://api.github.com/users/DylanGriffith/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/DylanGriffith/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'body': '- **Description:** In GitLab we call these "merge requests" rather than "pull requests" so I thought I\'d go ahead and update the notebook.\r\n- **Issue:** N/A\r\n- **Dependencies:** none\r\n- **Twitter handle:** N/A\r\n\r\nThanks for creating the tools and notebook to help people work with GitLab. I thought I\'d contribute some minor docs updates here.',
#   'created_at': '2024-08-22T00:59:10Z',
#   'updated_at': '2024-08-22T01:11:42Z',
#   'closed_at': None,
#   'merged_at': None,
#   'merge_commit_sha': 'a06c913ac976f0d078f9d8c00437bc700aaea5ab',
#   'assignee': None,
#   'assignees': [],
#   'requested_reviewers': [],
#   'requested_teams': [],
#   'labels': [{'id': 5680700918,
#     'node_id': 'LA_kwDOIPDwls8AAAABUpid9g',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%F0%9F%A4%96:docs',
#     'name': '🤖:docs',
#     'color': 'C5DEF5',
#     'default': False,
#     'description': 'Changes to documentation and examples, like .md, .rst, .ipynb files. Changes to the docs/ folder'},
#    {'id': 6232714108,
#     'node_id': 'LA_kwDOIPDwls8AAAABc3-rfA',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/size:S',
#     'name': 'size:S',
#     'color': 'BFDADC',
#     'default': False,
#     'description': 'This PR changes 10-29 lines, ignoring generated files.'}],
#   'milestone': None,
#   'draft': False,
#   'commits_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25649/commits',
#   'review_comments_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25649/comments',
#   'review_comment_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/comments{/number}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25649/comments',
#   'statuses_url': 'https://api.github.com/repos/langchain-ai/langchain/statuses/5cc193952f586b61871f225e5c5dc86188df1633',
#   'head': {'label': 'DylanGriffith:patch-1',
#    'ref': 'patch-1',
#    'sha': '5cc193952f586b61871f225e5c5dc86188df1633',
#    'user': {'login': 'DylanGriffith',
#     'id': 1002737,
#     'node_id': 'MDQ6VXNlcjEwMDI3Mzc=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/1002737?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/DylanGriffith',
#     'html_url': 'https://github.com/DylanGriffith',
#     'followers_url': 'https://api.github.com/users/DylanGriffith/followers',
#     'following_url': 'https://api.github.com/users/DylanGriffith/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/DylanGriffith/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/DylanGriffith/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/DylanGriffith/subscriptions',
#     'organizations_url': 'https://api.github.com/users/DylanGriffith/orgs',
#     'repos_url': 'https://api.github.com/users/DylanGriffith/repos',
#     'events_url': 'https://api.github.com/users/DylanGriffith/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/DylanGriffith/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'repo': {'id': 845806853,
#     'node_id': 'R_kgDOMmn9BQ',
#     'name': 'langchain',
#     'full_name': 'DylanGriffith/langchain',
#     'private': False,
#     'owner': {'login': 'DylanGriffith',
#      'id': 1002737,
#      'node_id': 'MDQ6VXNlcjEwMDI3Mzc=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/1002737?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/DylanGriffith',
#      'html_url': 'https://github.com/DylanGriffith',
#      'followers_url': 'https://api.github.com/users/DylanGriffith/followers',
#      'following_url': 'https://api.github.com/users/DylanGriffith/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/DylanGriffith/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/DylanGriffith/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/DylanGriffith/subscriptions',
#      'organizations_url': 'https://api.github.com/users/DylanGriffith/orgs',
#      'repos_url': 'https://api.github.com/users/DylanGriffith/repos',
#      'events_url': 'https://api.github.com/users/DylanGriffith/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/DylanGriffith/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/DylanGriffith/langchain',
#     'description': '🦜🔗 Build context-aware reasoning applications',
#     'fork': True,
#     'url': 'https://api.github.com/repos/DylanGriffith/langchain',
#     'forks_url': 'https://api.github.com/repos/DylanGriffith/langchain/forks',
#     'keys_url': 'https://api.github.com/repos/DylanGriffith/langchain/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/DylanGriffith/langchain/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/DylanGriffith/langchain/teams',
#     'hooks_url': 'https://api.github.com/repos/DylanGriffith/langchain/hooks',
#     'issue_events_url': 'https://api.github.com/repos/DylanGriffith/langchain/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/DylanGriffith/langchain/events',
#     'assignees_url': 'https://api.github.com/repos/DylanGriffith/langchain/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/DylanGriffith/langchain/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/DylanGriffith/langchain/tags',
#     'blobs_url': 'https://api.github.com/repos/DylanGriffith/langchain/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/DylanGriffith/langchain/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/DylanGriffith/langchain/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/DylanGriffith/langchain/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/DylanGriffith/langchain/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/DylanGriffith/langchain/languages',
#     'stargazers_url': 'https://api.github.com/repos/DylanGriffith/langchain/stargazers',
#     'contributors_url': 'https://api.github.com/repos/DylanGriffith/langchain/contributors',
#     'subscribers_url': 'https://api.github.com/repos/DylanGriffith/langchain/subscribers',
#     'subscription_url': 'https://api.github.com/repos/DylanGriffith/langchain/subscription',
#     'commits_url': 'https://api.github.com/repos/DylanGriffith/langchain/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/DylanGriffith/langchain/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/DylanGriffith/langchain/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/DylanGriffith/langchain/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/DylanGriffith/langchain/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/DylanGriffith/langchain/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/DylanGriffith/langchain/merges',
#     'archive_url': 'https://api.github.com/repos/DylanGriffith/langchain/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/DylanGriffith/langchain/downloads',
#     'issues_url': 'https://api.github.com/repos/DylanGriffith/langchain/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/DylanGriffith/langchain/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/DylanGriffith/langchain/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/DylanGriffith/langchain/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/DylanGriffith/langchain/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/DylanGriffith/langchain/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/DylanGriffith/langchain/deployments',
#     'created_at': '2024-08-22T00:53:14Z',
#     'updated_at': '2024-08-22T00:53:14Z',
#     'pushed_at': '2024-08-22T00:56:32Z',
#     'git_url': 'git://github.com/DylanGriffith/langchain.git',
#     'ssh_url': 'git@github.com:DylanGriffith/langchain.git',
#     'clone_url': 'https://github.com/DylanGriffith/langchain.git',
#     'svn_url': 'https://github.com/DylanGriffith/langchain',
#     'homepage': 'https://python.langchain.com',
#     'size': 290620,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'has_discussions': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': {'key': 'mit',
#      'name': 'MIT License',
#      'spdx_id': 'MIT',
#      'url': 'https://api.github.com/licenses/mit',
# ...
#    {'id': 6232714126,
#     'node_id': 'LA_kwDOIPDwls8AAAABc3-rjg',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/size:L',
#     'name': 'size:L',
#     'color': 'F9D0C4',
#     'default': False,
#     'description': 'This PR changes 100-499 lines, ignoring generated files.'},
#    {'id': 7097373342,
#     'node_id': 'LA_kwDOIPDwls8AAAABpwlSng',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/community',
#     'name': 'community',
#     'color': '579082',
#     'default': False,
#     'description': 'Related to langchain-community'}],
#   'milestone': None,
#   'draft': False,
#   'commits_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25527/commits',
#   'review_comments_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25527/comments',
#   'review_comment_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/comments{/number}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/25527/comments',
#   'statuses_url': 'https://api.github.com/repos/langchain-ai/langchain/statuses/e089efcee42b2803442c71880323abc34967d0fc',
#   'head': {'label': 'zysoong:zysoong/prompt-injection-for-tools',
#    'ref': 'zysoong/prompt-injection-for-tools',
#    'sha': 'e089efcee42b2803442c71880323abc34967d0fc',
#    'user': {'login': 'zysoong',
#     'id': 75294755,
#     'node_id': 'MDQ6VXNlcjc1Mjk0NzU1',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/75294755?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/zysoong',
#     'html_url': 'https://github.com/zysoong',
#     'followers_url': 'https://api.github.com/users/zysoong/followers',
#     'following_url': 'https://api.github.com/users/zysoong/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/zysoong/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/zysoong/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/zysoong/subscriptions',
#     'organizations_url': 'https://api.github.com/users/zysoong/orgs',
#     'repos_url': 'https://api.github.com/users/zysoong/repos',
#     'events_url': 'https://api.github.com/users/zysoong/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/zysoong/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'repo': {'id': 843760110,
#     'node_id': 'R_kgDOMkrB7g',
#     'name': 'langchain',
#     'full_name': 'zysoong/langchain',
#     'private': False,
#     'owner': {'login': 'zysoong',
#      'id': 75294755,
#      'node_id': 'MDQ6VXNlcjc1Mjk0NzU1',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/75294755?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/zysoong',
#      'html_url': 'https://github.com/zysoong',
#      'followers_url': 'https://api.github.com/users/zysoong/followers',
#      'following_url': 'https://api.github.com/users/zysoong/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/zysoong/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/zysoong/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/zysoong/subscriptions',
#      'organizations_url': 'https://api.github.com/users/zysoong/orgs',
#      'repos_url': 'https://api.github.com/users/zysoong/repos',
#      'events_url': 'https://api.github.com/users/zysoong/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/zysoong/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/zysoong/langchain',
#     'description': '🦜🔗 Build context-aware reasoning applications',
#     'fork': True,
#     'url': 'https://api.github.com/repos/zysoong/langchain',
#     'forks_url': 'https://api.github.com/repos/zysoong/langchain/forks',
#     'keys_url': 'https://api.github.com/repos/zysoong/langchain/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/zysoong/langchain/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/zysoong/langchain/teams',
#     'hooks_url': 'https://api.github.com/repos/zysoong/langchain/hooks',
#     'issue_events_url': 'https://api.github.com/repos/zysoong/langchain/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/zysoong/langchain/events',
#     'assignees_url': 'https://api.github.com/repos/zysoong/langchain/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/zysoong/langchain/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/zysoong/langchain/tags',
#     'blobs_url': 'https://api.github.com/repos/zysoong/langchain/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/zysoong/langchain/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/zysoong/langchain/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/zysoong/langchain/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/zysoong/langchain/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/zysoong/langchain/languages',
#     'stargazers_url': 'https://api.github.com/repos/zysoong/langchain/stargazers',
#     'contributors_url': 'https://api.github.com/repos/zysoong/langchain/contributors',
#     'subscribers_url': 'https://api.github.com/repos/zysoong/langchain/subscribers',
#     'subscription_url': 'https://api.github.com/repos/zysoong/langchain/subscription',
#     'commits_url': 'https://api.github.com/repos/zysoong/langchain/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/zysoong/langchain/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/zysoong/langchain/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/zysoong/langchain/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/zysoong/langchain/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/zysoong/langchain/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/zysoong/langchain/merges',
#     'archive_url': 'https://api.github.com/repos/zysoong/langchain/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/zysoong/langchain/downloads',
#     'issues_url': 'https://api.github.com/repos/zysoong/langchain/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/zysoong/langchain/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/zysoong/langchain/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/zysoong/langchain/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/zysoong/langchain/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/zysoong/langchain/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/zysoong/langchain/deployments',
#     'created_at': '2024-08-17T10:36:33Z',
#     'updated_at': '2024-08-18T10:16:18Z',
#     'pushed_at': '2024-08-18T13:14:13Z',
#     'git_url': 'git://github.com/zysoong/langchain.git',
#     'ssh_url': 'git@github.com:zysoong/langchain.git',
#     'clone_url': 'https://github.com/zysoong/langchain.git',
#     'svn_url': 'https://github.com/zysoong/langchain',
#     'homepage': 'https://python.langchain.com',
#     'size': 234940,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': 'Jupyter Notebook',
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'has_discussions': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': {'key': 'mit',
#      'name': 'MIT License',
#      'spdx_id': 'MIT',
#      'url': 'https://api.github.com/licenses/mit',
#      'node_id': 'MDc6TGljZW5zZTEz'},
#     'allow_forking': True,
#     'is_template': False,
#     'web_commit_signoff_required': False,
#     'topics': [],
#     'visibility': 'public',
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'master'}},
#   'base': {'label': 'langchain-ai:master',
#    'ref': 'master',
#    'sha': 'bda3becbe77a22ce49d77c59035727f3b2ed64f1',
#    'user': {'login': 'langchain-ai',
#     'id': 126733545,
#     'node_id': 'O_kgDOB43M6Q',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/126733545?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/langchain-ai',
#     'html_url': 'https://github.com/langchain-ai',
#     'followers_url': 'https://api.github.com/users/langchain-ai/followers',
#     'following_url': 'https://api.github.com/users/langchain-ai/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/langchain-ai/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/langchain-ai/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/langchain-ai/subscriptions',
#     'organizations_url': 'https://api.github.com/users/langchain-ai/orgs',
#     'repos_url': 'https://api.github.com/users/langchain-ai/repos',
#     'events_url': 'https://api.github.com/users/langchain-ai/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/langchain-ai/received_events',
#     'type': 'Organization',
#     'site_admin': False},
#    'repo': {'id': 552661142,
#     'node_id': 'R_kgDOIPDwlg',
#     'name': 'langchain',
#     'full_name': 'langchain-ai/langchain',
#     'private': False,
#     'owner': {'login': 'langchain-ai',
#      'id': 126733545,
#      'node_id': 'O_kgDOB43M6Q',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/126733545?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/langchain-ai',
#      'html_url': 'https://github.com/langchain-ai',
#      'followers_url': 'https://api.github.com/users/langchain-ai/followers',
#      'following_url': 'https://api.github.com/users/langchain-ai/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/langchain-ai/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/langchain-ai/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/langchain-ai/subscriptions',
#      'organizations_url': 'https://api.github.com/users/langchain-ai/orgs',
#      'repos_url': 'https://api.github.com/users/langchain-ai/repos',
#      'events_url': 'https://api.github.com/users/langchain-ai/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/langchain-ai/received_events',
#      'type': 'Organization',
#      'site_admin': False},
#     'html_url': 'https://github.com/langchain-ai/langchain',
#     'description': '🦜🔗 Build context-aware reasoning applications',
#     'fork': False,
#     'url': 'https://api.github.com/repos/langchain-ai/langchain',
#     'forks_url': 'https://api.github.com/repos/langchain-ai/langchain/forks',
#     'keys_url': 'https://api.github.com/repos/langchain-ai/langchain/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/langchain-ai/langchain/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/langchain-ai/langchain/teams',
#     'hooks_url': 'https://api.github.com/repos/langchain-ai/langchain/hooks',
#     'issue_events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/langchain-ai/langchain/events',
#     'assignees_url': 'https://api.github.com/repos/langchain-ai/langchain/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/langchain-ai/langchain/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/langchain-ai/langchain/tags',
#     'blobs_url': 'https://api.github.com/repos/langchain-ai/langchain/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/langchain-ai/langchain/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/langchain-ai/langchain/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/langchain-ai/langchain/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/langchain-ai/langchain/languages',
#     'stargazers_url': 'https://api.github.com/repos/langchain-ai/langchain/stargazers',
#     'contributors_url': 'https://api.github.com/repos/langchain-ai/langchain/contributors',
#     'subscribers_url': 'https://api.github.com/repos/langchain-ai/langchain/subscribers',
#     'subscription_url': 'https://api.github.com/repos/langchain-ai/langchain/subscription',
#     'commits_url': 'https://api.github.com/repos/langchain-ai/langchain/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/langchain-ai/langchain/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/langchain-ai/langchain/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/langchain-ai/langchain/merges',
#     'archive_url': 'https://api.github.com/repos/langchain-ai/langchain/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/langchain-ai/langchain/downloads',
#     'issues_url': 'https://api.github.com/repos/langchain-ai/langchain/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/langchain-ai/langchain/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/langchain-ai/langchain/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/langchain-ai/langchain/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/langchain-ai/langchain/deployments',
#     'created_at': '2022-10-17T02:58:36Z',
#     'updated_at': '2024-08-22T03:49:13Z',
#     'pushed_at': '2024-08-22T04:12:00Z',
#     'git_url': 'git://github.com/langchain-ai/langchain.git',
#     'ssh_url': 'git@github.com:langchain-ai/langchain.git',
#     'clone_url': 'https://github.com/langchain-ai/langchain.git',
#     'svn_url': 'https://github.com/langchain-ai/langchain',
#     'homepage': 'https://python.langchain.com',
#     'size': 290611,
#     'stargazers_count': 91030,
#     'watchers_count': 91030,
#     'language': 'Jupyter Notebook',
#     'has_issues': True,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'has_discussions': True,
#     'forks_count': 14469,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 1011,
#     'license': {'key': 'mit',
#      'name': 'MIT License',
#      'spdx_id': 'MIT',
#      'url': 'https://api.github.com/licenses/mit',
#      'node_id': 'MDc6TGljZW5zZTEz'},
#     'allow_forking': True,
#     'is_template': False,
#     'web_commit_signoff_required': False,
#     'topics': [],
#     'visibility': 'public',
#     'forks': 14469,
#     'open_issues': 1011,
#     'watchers': 91030,
#     'default_branch': 'master'}},
#   '_links': {'self': {'href': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25527'},
#    'html': {'href': 'https://github.com/langchain-ai/langchain/pull/25527'},
#    'issue': {'href': 'https://api.github.com/repos/langchain-ai/langchain/issues/25527'},
#    'comments': {'href': 'https://api.github.com/repos/langchain-ai/langchain/issues/25527/comments'},
#    'review_comments': {'href': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25527/comments'},
#    'review_comment': {'href': 'https://api.github.com/repos/langchain-ai/langchain/pulls/comments{/number}'},
#    'commits': {'href': 'https://api.github.com/repos/langchain-ai/langchain/pulls/25527/commits'},
#    'statuses': {'href': 'https://api.github.com/repos/langchain-ai/langchain/statuses/e089efcee42b2803442c71880323abc34967d0fc'}},
#   'author_association': 'NONE',
#   'auto_merge': None,
#   'active_lock_reason': None}]

# %% [markdown]
# ### List Commits API
#
# API完整文档说明见：https://docs.github.com/en/rest/commits/commits?apiVersion=2022-11-28
#
# **请求样例**：`GET /repos/{owner}/{repo}/commits`;

# %%
commits = github_client.fetch_commits(repo)

# %%
commits
# Out:
# [{'sha': 'e958f76160c6542072c7bd334fbb3c21d327e8bc',
#   'node_id': 'C_kwDOIPDwltoAKGU5NThmNzYxNjBjNjU0MjA3MmM3YmQzMzRmYmIzYzIxZDMyN2U4YmM',
#   'commit': {'author': {'name': 'Erick Friis',
#     'email': 'erick@langchain.dev',
#     'date': '2024-08-22T04:24:34Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2024-08-22T04:24:34Z'},
#    'message': 'docs: migration guide nits (#25600)',
#    'tree': {'sha': 'bd7a07a6481abd71d6048b37b436c9676b61ce7f',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees/bd7a07a6481abd71d6048b37b436c9676b61ce7f'},
#    'url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits/e958f76160c6542072c7bd334fbb3c21d327e8bc',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\nK0ZyfIX/qnknKEwEMvTI\n=o/FL\n-----END PGP SIGNATURE-----\n',
#     'payload': 'tree bd7a07a6481abd71d6048b37b436c9676b61ce7f\nparent 3981d736df7b113346670f4e26cb8ee0ecaa656e\nauthor Erick Friis <erick@langchain.dev> 1724300674 -0700\ncommitter GitHub <noreply@github.com> 1724300674 +0000\n\ndocs: migration guide nits (#25600)\n\n'}},
#   'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/e958f76160c6542072c7bd334fbb3c21d327e8bc',
#   'html_url': 'https://github.com/langchain-ai/langchain/commit/e958f76160c6542072c7bd334fbb3c21d327e8bc',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/commits/e958f76160c6542072c7bd334fbb3c21d327e8bc/comments',
#   'author': {'login': 'efriis',
#    'id': 9557659,
#    'node_id': 'MDQ6VXNlcjk1NTc2NTk=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/9557659?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/efriis',
#    'html_url': 'https://github.com/efriis',
#    'followers_url': 'https://api.github.com/users/efriis/followers',
#    'following_url': 'https://api.github.com/users/efriis/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/efriis/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/efriis/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/efriis/subscriptions',
#    'organizations_url': 'https://api.github.com/users/efriis/orgs',
#    'repos_url': 'https://api.github.com/users/efriis/repos',
#    'events_url': 'https://api.github.com/users/efriis/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/efriis/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'parents': [{'sha': '3981d736df7b113346670f4e26cb8ee0ecaa656e',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/3981d736df7b113346670f4e26cb8ee0ecaa656e',
#     'html_url': 'https://github.com/langchain-ai/langchain/commit/3981d736df7b113346670f4e26cb8ee0ecaa656e'}]},
#  {'sha': '3981d736df7b113346670f4e26cb8ee0ecaa656e',
#   'node_id': 'C_kwDOIPDwltoAKDM5ODFkNzM2ZGY3YjExMzM0NjY3MGY0ZTI2Y2I4ZWUwZWNhYTY1NmU',
#   'commit': {'author': {'name': 'Yuki Watanabe',
#     'email': '31463517+B-Step62@users.noreply.github.com',
#     'date': '2024-08-22T00:19:28Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2024-08-22T00:19:28Z'},
#    'message': 'databricks: Add partner package directory and ChatDatabricks implementation (#25430)\n\n### Summary\r\n\r\nCreate `langchain-databricks` as a new partner packages. This PR does\r\nnot migrate all existing Databricks integration, but the package will\r\neventually contain:\r\n\r\n* `ChatDatabricks` (implemented in this PR)\r\n* `DatabricksVectorSearch`\r\n* `DatabricksEmbeddings`\r\n* ~`UCFunctionToolkit`~ (will be done after UC SDK work which\r\ndrastically simplify implementation)\r\n\r\nAlso, this PR does not add integration tests yet. This will be added\r\nonce the Databricks test workspace is ready.\r\n\r\nTagging @efriis as POC\r\n\r\n\r\n### Tracker\r\n[✍️] Create a package and imgrate ChatDatabricks\r\n[ ] Migrate DatabricksVectorSearch, DatabricksEmbeddings, and their docs\r\n~[ ] Migrate UCFunctionToolkit and its doc~\r\n[ ] Add provider document and update README.md\r\n[ ] Add integration tests and set up secrets (after moved to an external\r\npackage)\r\n[ ] Add deprecation note to the community implementations.\r\n\r\n---------\r\n\r\nSigned-off-by: B-Step62 <yuki.watanabe@databricks.com>\r\nCo-authored-by: Erick Friis <erick@langchain.dev>',
#    'tree': {'sha': '7c61089e90432ea2d9645ba82dc2a7021ca4cffd',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees/7c61089e90432ea2d9645ba82dc2a7021ca4cffd'},
#    'url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits/3981d736df7b113346670f4e26cb8ee0ecaa656e',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\nPO2Xr1SI6al2gtzxU8sE\n=PrRF\n-----END PGP SIGNATURE-----\n',
#     'payload': 'tree 7c61089e90432ea2d9645ba82dc2a7021ca4cffd\nparent fb1d67edf6f667d7f32820b16d63de93512b2c6d\nauthor Yuki Watanabe <31463517+B-Step62@users.noreply.github.com> 1724285968 +0900\ncommitter GitHub <noreply@github.com> 1724285968 -0700\n\ndatabricks: Add partner package directory and ChatDatabricks implementation (#25430)\n\n### Summary\r\n\r\nCreate `langchain-databricks` as a new partner packages. This PR does\r\nnot migrate all existing Databricks integration, but the package will\r\neventually contain:\r\n\r\n* `ChatDatabricks` (implemented in this PR)\r\n* `DatabricksVectorSearch`\r\n* `DatabricksEmbeddings`\r\n* ~`UCFunctionToolkit`~ (will be done after UC SDK work which\r\ndrastically simplify implementation)\r\n\r\nAlso, this PR does not add integration tests yet. This will be added\r\nonce the Databricks test workspace is ready.\r\n\r\nTagging @efriis as POC\r\n\r\n\r\n### Tracker\r\n[✍️] Create a package and imgrate ChatDatabricks\r\n[ ] Migrate DatabricksVectorSearch, DatabricksEmbeddings, and their docs\r\n~[ ] Migrate UCFunctionToolkit and its doc~\r\n[ ] Add provider document and update README.md\r\n[ ] Add integration tests and set up secrets (after moved to an external\r\npackage)\r\n[ ] Add deprecation note to the community implementations.\r\n\r\n---------\r\n\r\nSigned-off-by: B-Step62 <yuki.watanabe@databricks.com>\r\nCo-authored-by: Erick Friis <erick@langchain.dev>'}},
#   'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/3981d736df7b113346670f4e26cb8ee0ecaa656e',
#   'html_url': 'https://github.com/langchain-ai/langchain/commit/3981d736df7b113346670f4e26cb8ee0ecaa656e',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/commits/3981d736df7b113346670f4e26cb8ee0ecaa656e/comments',
#   'author': {'login': 'B-Step62',
#    'id': 31463517,
#    'node_id': 'MDQ6VXNlcjMxNDYzNTE3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/31463517?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/B-Step62',
#    'html_url': 'https://github.com/B-Step62',
#    'followers_url': 'https://api.github.com/users/B-Step62/followers',
#    'following_url': 'https://api.github.com/users/B-Step62/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/B-Step62/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/B-Step62/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/B-Step62/subscriptions',
#    'organizations_url': 'https://api.github.com/users/B-Step62/orgs',
#    'repos_url': 'https://api.github.com/users/B-Step62/repos',
#    'events_url': 'https://api.github.com/users/B-Step62/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/B-Step62/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'parents': [{'sha': 'fb1d67edf6f667d7f32820b16d63de93512b2c6d',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/fb1d67edf6f667d7f32820b16d63de93512b2c6d',
#     'html_url': 'https://github.com/langchain-ai/langchain/commit/fb1d67edf6f667d7f32820b16d63de93512b2c6d'}]},
#  {'sha': 'fb1d67edf6f667d7f32820b16d63de93512b2c6d',
#   'node_id': 'C_kwDOIPDwltoAKGZiMWQ2N2VkZjZmNjY3ZDdmMzI4MjBiMTZkNjNkZTkzNTEyYjJjNmQ',
#   'commit': {'author': {'name': 'Scott Hurrey',
#     'email': 'scott.hurrey@gmail.com',
#     'date': '2024-08-21T22:40:40Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2024-08-21T22:40:40Z'},
#    'message': "box: add retrievers and fix docs (#25633)\n\nThank you for contributing to LangChain!\r\n\r\n\r\n**Description:** Adding `BoxRetriever` for langchain_box. This retriever\r\nhandles two use cases:\r\n* Retrieve all documents that match a full-text search\r\n* Retrieve the answer to a Box AI prompt as a Document\r\n\r\n**Twitter handle:** @BoxPlatform\r\n\r\n\r\n- [x] **Add tests and docs**: If you're adding a new integration, please\r\ninclude\r\n1. a test for the integration, preferably unit tests that do not rely on\r\nnetwork access,\r\n2. an example notebook showing its use. It lives in\r\n`docs/docs/integrations` directory.\r\n\r\n\r\n- [x] **Lint and test**: Run `make format`, `make lint` and `make test`\r\nfrom the root of the package(s) you've modified. See contribution\r\nguidelines for more: https://python.langchain.com/docs/contributing/\r\n\r\nAdditional guidelines:\r\n- Make sure optional dependencies are imported within a function.\r\n- Please do not add dependencies to pyproject.toml files (even optional\r\nones) unless they are required for unit tests.\r\n- Most PRs should not touch more than one package.\r\n- Changes should be backwards compatible.\r\n- If you are adding something to community, do not re-import it in\r\nlangchain.\r\n\r\nIf no one reviews your PR within a few days, please @-mention one of\r\nbaskaryan, efriis, eyurtsev, ccurme, vbarda, hwchase17.\r\n\r\n---------\r\n\r\nCo-authored-by: Erick Friis <erick@langchain.dev>",
#    'tree': {'sha': '8721adccdba5bfdf59091fa779a03d04fd08f4a2',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees/8721adccdba5bfdf59091fa779a03d04fd08f4a2'},
#    'url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits/fb1d67edf6f667d7f32820b16d63de93512b2c6d',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\n9BoPK0KMl/XmZx41kEBn\n=1WnN\n-----END PGP SIGNATURE-----\n',
#     'payload': "tree 8721adccdba5bfdf59091fa779a03d04fd08f4a2\nparent 4f347cbcb98c94fa3936321c934c6fc42bd6920e\nauthor Scott Hurrey <scott.hurrey@gmail.com> 1724280040 -0400\ncommitter GitHub <noreply@github.com> 1724280040 +0000\n\nbox: add retrievers and fix docs (#25633)\n\nThank you for contributing to LangChain!\r\n\r\n\r\n**Description:** Adding `BoxRetriever` for langchain_box. This retriever\r\nhandles two use cases:\r\n* Retrieve all documents that match a full-text search\r\n* Retrieve the answer to a Box AI prompt as a Document\r\n\r\n**Twitter handle:** @BoxPlatform\r\n\r\n\r\n- [x] **Add tests and docs**: If you're adding a new integration, please\r\ninclude\r\n1. a test for the integration, preferably unit tests that do not rely on\r\nnetwork access,\r\n2. an example notebook showing its use. It lives in\r\n`docs/docs/integrations` directory.\r\n\r\n\r\n- [x] **Lint and test**: Run `make format`, `make lint` and `make test`\r\nfrom the root of the package(s) you've modified. See contribution\r\nguidelines for more: https://python.langchain.com/docs/contributing/\r\n\r\nAdditional guidelines:\r\n- Make sure optional dependencies are imported within a function.\r\n- Please do not add dependencies to pyproject.toml files (even optional\r\nones) unless they are required for unit tests.\r\n- Most PRs should not touch more than one package.\r\n- Changes should be backwards compatible.\r\n- If you are adding something to community, do not re-import it in\r\nlangchain.\r\n\r\nIf no one reviews your PR within a few days, please @-mention one of\r\nbaskaryan, efriis, eyurtsev, ccurme, vbarda, hwchase17.\r\n\r\n---------\r\n\r\nCo-authored-by: Erick Friis <erick@langchain.dev>"}},
#   'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/fb1d67edf6f667d7f32820b16d63de93512b2c6d',
#   'html_url': 'https://github.com/langchain-ai/langchain/commit/fb1d67edf6f667d7f32820b16d63de93512b2c6d',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/commits/fb1d67edf6f667d7f32820b16d63de93512b2c6d/comments',
#   'author': {'login': 'shurrey',
#    'id': 886516,
#    'node_id': 'MDQ6VXNlcjg4NjUxNg==',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/886516?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/shurrey',
#    'html_url': 'https://github.com/shurrey',
#    'followers_url': 'https://api.github.com/users/shurrey/followers',
#    'following_url': 'https://api.github.com/users/shurrey/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/shurrey/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/shurrey/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/shurrey/subscriptions',
#    'organizations_url': 'https://api.github.com/users/shurrey/orgs',
#    'repos_url': 'https://api.github.com/users/shurrey/repos',
#    'events_url': 'https://api.github.com/users/shurrey/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/shurrey/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'parents': [{'sha': '4f347cbcb98c94fa3936321c934c6fc42bd6920e',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/4f347cbcb98c94fa3936321c934c6fc42bd6920e',
#     'html_url': 'https://github.com/langchain-ai/langchain/commit/4f347cbcb98c94fa3936321c934c6fc42bd6920e'}]},
#  {'sha': '4f347cbcb98c94fa3936321c934c6fc42bd6920e',
#   'node_id': 'C_kwDOIPDwltoAKDRmMzQ3Y2JjYjk4Yzk0ZmEzOTM2MzIxYzkzNGM2ZmM0MmJkNjkyMGU',
#   'commit': {'author': {'name': 'Bagatur',
#     'email': '22008038+baskaryan@users.noreply.github.com',
#     'date': '2024-08-21T21:02:25Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2024-08-21T21:02:25Z'},
#    'message': 'docs: link Versions in intro (#25640)',
#    'tree': {'sha': 'afe255a50a7717feb04e6fff0ef22dc0cf3ee0a5',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees/afe255a50a7717feb04e6fff0ef22dc0cf3ee0a5'},
#    'url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits/4f347cbcb98c94fa3936321c934c6fc42bd6920e',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\nnShEKflNQtyaQD+0ZBHO\n=sSns\n-----END PGP SIGNATURE-----\n',
#     'payload': 'tree afe255a50a7717feb04e6fff0ef22dc0cf3ee0a5\nparent 4591bc0b01d9618b0d4af1f1d65cba2e8b411be8\nauthor Bagatur <22008038+baskaryan@users.noreply.github.com> 1724274145 -0700\ncommitter GitHub <noreply@github.com> 1724274145 +0000\n\ndocs: link Versions in intro (#25640)\n\n'}},
#   'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/4f347cbcb98c94fa3936321c934c6fc42bd6920e',
#   'html_url': 'https://github.com/langchain-ai/langchain/commit/4f347cbcb98c94fa3936321c934c6fc42bd6920e',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/commits/4f347cbcb98c94fa3936321c934c6fc42bd6920e/comments',
#   'author': {'login': 'baskaryan',
#    'id': 22008038,
#    'node_id': 'MDQ6VXNlcjIyMDA4MDM4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22008038?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/baskaryan',
#    'html_url': 'https://github.com/baskaryan',
#    'followers_url': 'https://api.github.com/users/baskaryan/followers',
#    'following_url': 'https://api.github.com/users/baskaryan/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/baskaryan/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/baskaryan/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/baskaryan/subscriptions',
#    'organizations_url': 'https://api.github.com/users/baskaryan/orgs',
#    'repos_url': 'https://api.github.com/users/baskaryan/repos',
#    'events_url': 'https://api.github.com/users/baskaryan/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/baskaryan/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'parents': [{'sha': '4591bc0b01d9618b0d4af1f1d65cba2e8b411be8',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/4591bc0b01d9618b0d4af1f1d65cba2e8b411be8',
#     'html_url': 'https://github.com/langchain-ai/langchain/commit/4591bc0b01d9618b0d4af1f1d65cba2e8b411be8'}]},
#  {'sha': '4591bc0b01d9618b0d4af1f1d65cba2e8b411be8',
#   'node_id': 'C_kwDOIPDwltoAKDQ1OTFiYzBiMDFkOTYxOGIwZDRhZjFmMWQ2NWNiYTJlOGI0MTFiZTg',
#   'commit': {'author': {'name': 'jakerachleff',
#     'email': 'jake@langchain.dev',
#     'date': '2024-08-21T21:02:01Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2024-08-21T21:02:01Z'},
#    'message': 'Use 1.101 instead of 1.100 bc 1.100 was yanked (#25638)',
#    'tree': {'sha': '0f6d494a8fa417b260177471646f06a384bd49ab',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees/0f6d494a8fa417b260177471646f06a384bd49ab'},
#    'url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits/4591bc0b01d9618b0d4af1f1d65cba2e8b411be8',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\np3MWomOv/j/nOqJlfx+A\n=7o2t\n-----END PGP SIGNATURE-----\n',
#     'payload': 'tree 0f6d494a8fa417b260177471646f06a384bd49ab\nparent f535e8a99e0ad8fa342785b3b309046a66940333\nauthor jakerachleff <jake@langchain.dev> 1724274121 -0700\ncommitter GitHub <noreply@github.com> 1724274121 +0000\n\nUse 1.101 instead of 1.100 bc 1.100 was yanked (#25638)\n\n'}},
#   'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/4591bc0b01d9618b0d4af1f1d65cba2e8b411be8',
#   'html_url': 'https://github.com/langchain-ai/langchain/commit/4591bc0b01d9618b0d4af1f1d65cba2e8b411be8',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/commits/4591bc0b01d9618b0d4af1f1d65cba2e8b411be8/comments',
#   'author': {'login': 'jakerachleff',
#    'id': 9028897,
#    'node_id': 'MDQ6VXNlcjkwMjg4OTc=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/9028897?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jakerachleff',
#    'html_url': 'https://github.com/jakerachleff',
#    'followers_url': 'https://api.github.com/users/jakerachleff/followers',
#    'following_url': 'https://api.github.com/users/jakerachleff/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jakerachleff/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jakerachleff/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jakerachleff/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jakerachleff/orgs',
#    'repos_url': 'https://api.github.com/users/jakerachleff/repos',
#    'events_url': 'https://api.github.com/users/jakerachleff/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jakerachleff/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'parents': [{'sha': 'f535e8a99e0ad8fa342785b3b309046a66940333',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/f535e8a99e0ad8fa342785b3b309046a66940333',
#     'html_url': 'https://github.com/langchain-ai/langchain/commit/f535e8a99e0ad8fa342785b3b309046a66940333'}]},
#  {'sha': 'f535e8a99e0ad8fa342785b3b309046a66940333',
#   'node_id': 'C_kwDOIPDwltoAKGY1MzVlOGE5OWUwYWQ4ZmEzNDI3ODViM2IzMDkwNDZhNjY5NDAzMzM',
#   'commit': {'author': {'name': 'Bagatur',
#     'email': '22008038+baskaryan@users.noreply.github.com',
#     'date': '2024-08-21T20:50:24Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2024-08-21T20:50:24Z'},
#    'message': 'docs: ls similar examples header (#25642)',
#    'tree': {'sha': 'c16a16a150da2e1057592ac4d4b718a98994aa0a',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees/c16a16a150da2e1057592ac4d4b718a98994aa0a'},
#    'url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits/f535e8a99e0ad8fa342785b3b309046a66940333',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\nnmlbA+bsNEKBN1iZ8NaW\n=FNIC\n-----END PGP SIGNATURE-----\n',
#     'payload': 'tree c16a16a150da2e1057592ac4d4b718a98994aa0a\nparent 766b650fdca6ae0b55f884b4b5d89a9591cbd248\nauthor Bagatur <22008038+baskaryan@users.noreply.github.com> 1724273424 -0700\ncommitter GitHub <noreply@github.com> 1724273424 +0000\n\ndocs: ls similar examples header (#25642)\n\n'}},
#   'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/f535e8a99e0ad8fa342785b3b309046a66940333',
#   'html_url': 'https://github.com/langchain-ai/langchain/commit/f535e8a99e0ad8fa342785b3b309046a66940333',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/commits/f535e8a99e0ad8fa342785b3b309046a66940333/comments',
#   'author': {'login': 'baskaryan',
#    'id': 22008038,
#    'node_id': 'MDQ6VXNlcjIyMDA4MDM4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22008038?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/baskaryan',
#    'html_url': 'https://github.com/baskaryan',
#    'followers_url': 'https://api.github.com/users/baskaryan/followers',
#    'following_url': 'https://api.github.com/users/baskaryan/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/baskaryan/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/baskaryan/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/baskaryan/subscriptions',
#    'organizations_url': 'https://api.github.com/users/baskaryan/orgs',
#    'repos_url': 'https://api.github.com/users/baskaryan/repos',
#    'events_url': 'https://api.github.com/users/baskaryan/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/baskaryan/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'parents': [{'sha': '766b650fdca6ae0b55f884b4b5d89a9591cbd248',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/766b650fdca6ae0b55f884b4b5d89a9591cbd248',
#     'html_url': 'https://github.com/langchain-ai/langchain/commit/766b650fdca6ae0b55f884b4b5d89a9591cbd248'}]},
#  {'sha': '766b650fdca6ae0b55f884b4b5d89a9591cbd248',
#   'node_id': 'C_kwDOIPDwltoAKDc2NmI2NTBmZGNhNmFlMGI1NWY4ODRiNGI1ZDg5YTk1OTFjYmQyNDg',
#   'commit': {'author': {'name': 'Erick Friis',
#     'email': 'erick@langchain.dev',
#     'date': '2024-08-21T20:00:47Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2024-08-21T20:00:47Z'},
#    'message': 'chroma: add back fastapi optional dep (#25641)',
#    'tree': {'sha': '7e20d67a05cd5efa56e220a9fa37bdf22ddda7a2',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees/7e20d67a05cd5efa56e220a9fa37bdf22ddda7a2'},
#    'url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits/766b650fdca6ae0b55f884b4b5d89a9591cbd248',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\nNweiZhtDh2wM43TRZ5jH\n=606K\n-----END PGP SIGNATURE-----\n',
#     'payload': 'tree 7e20d67a05cd5efa56e220a9fa37bdf22ddda7a2\nparent 9daff60698695417a0e7e11e634d5b38639c0c04\nauthor Erick Friis <erick@langchain.dev> 1724270447 -0700\ncommitter GitHub <noreply@github.com> 1724270447 +0000\n\nchroma: add back fastapi optional dep (#25641)\n\n'}},
#   'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/766b650fdca6ae0b55f884b4b5d89a9591cbd248',
#   'html_url': 'https://github.com/langchain-ai/langchain/commit/766b650fdca6ae0b55f884b4b5d89a9591cbd248',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/commits/766b650fdca6ae0b55f884b4b5d89a9591cbd248/comments',
#   'author': {'login': 'efriis',
#    'id': 9557659,
#    'node_id': 'MDQ6VXNlcjk1NTc2NTk=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/9557659?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/efriis',
#    'html_url': 'https://github.com/efriis',
#    'followers_url': 'https://api.github.com/users/efriis/followers',
#    'following_url': 'https://api.github.com/users/efriis/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/efriis/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/efriis/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/efriis/subscriptions',
#    'organizations_url': 'https://api.github.com/users/efriis/orgs',
#    'repos_url': 'https://api.github.com/users/efriis/repos',
#    'events_url': 'https://api.github.com/users/efriis/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/efriis/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'parents': [{'sha': '9daff60698695417a0e7e11e634d5b38639c0c04',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/9daff60698695417a0e7e11e634d5b38639c0c04',
#     'html_url': 'https://github.com/langchain-ai/langchain/commit/9daff60698695417a0e7e11e634d5b38639c0c04'}]},
#  {'sha': '9daff60698695417a0e7e11e634d5b38639c0c04',
#   'node_id': 'C_kwDOIPDwltoAKDlkYWZmNjA2OTg2OTU0MTdhMGU3ZTExZTYzNGQ1YjM4NjM5YzBjMDQ',
#   'commit': {'author': {'name': 'Bagatur',
#     'email': '22008038+baskaryan@users.noreply.github.com',
#     'date': '2024-08-21T19:55:17Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2024-08-21T19:55:17Z'},
#    'message': 'docs: fix openai api ref (#25639)',
#    'tree': {'sha': '859db438834546a26825d436f7983f956a799da6',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees/859db438834546a26825d436f7983f956a799da6'},
#    'url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits/9daff60698695417a0e7e11e634d5b38639c0c04',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\n7oU2Jl4Ge4ouOI7zeb5k\n=+oJI\n-----END PGP SIGNATURE-----\n',
#     'payload': 'tree 859db438834546a26825d436f7983f956a799da6\nparent c8be0a9f7071f9143636a1c29e0582ccb1dc5039\nauthor Bagatur <22008038+baskaryan@users.noreply.github.com> 1724270117 -0700\ncommitter GitHub <noreply@github.com> 1724270117 -0700\n\ndocs: fix openai api ref (#25639)\n\n'}},
#   'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/9daff60698695417a0e7e11e634d5b38639c0c04',
#   'html_url': 'https://github.com/langchain-ai/langchain/commit/9daff60698695417a0e7e11e634d5b38639c0c04',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/commits/9daff60698695417a0e7e11e634d5b38639c0c04/comments',
#   'author': {'login': 'baskaryan',
#    'id': 22008038,
#    'node_id': 'MDQ6VXNlcjIyMDA4MDM4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22008038?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/baskaryan',
#    'html_url': 'https://github.com/baskaryan',
#    'followers_url': 'https://api.github.com/users/baskaryan/followers',
#    'following_url': 'https://api.github.com/users/baskaryan/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/baskaryan/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/baskaryan/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/baskaryan/subscriptions',
#    'organizations_url': 'https://api.github.com/users/baskaryan/orgs',
#    'repos_url': 'https://api.github.com/users/baskaryan/repos',
#    'events_url': 'https://api.github.com/users/baskaryan/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/baskaryan/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'parents': [{'sha': 'c8be0a9f7071f9143636a1c29e0582ccb1dc5039',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/c8be0a9f7071f9143636a1c29e0582ccb1dc5039',
#     'html_url': 'https://github.com/langchain-ai/langchain/commit/c8be0a9f7071f9143636a1c29e0582ccb1dc5039'}]},
#  {'sha': 'c8be0a9f7071f9143636a1c29e0582ccb1dc5039',
#   'node_id': 'C_kwDOIPDwltoAKGM4YmUwYTlmNzA3MWY5MTQzNjM2YTFjMjllMDU4MmNjYjFkYzUwMzk',
#   'commit': {'author': {'name': 'Erick Friis',
#     'email': 'erick@langchain.dev',
#     'date': '2024-08-21T19:53:55Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2024-08-21T19:53:55Z'},
#    'message': 'partners/unstructured: release 0.1.2 (#25637)',
#    'tree': {'sha': '7caa32961a33f35f6c482d6331f7e2c1a6ac27fa',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees/7caa32961a33f35f6c482d6331f7e2c1a6ac27fa'},
#    'url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits/c8be0a9f7071f9143636a1c29e0582ccb1dc5039',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\nhQ7I+FQTwZcmxKh2A4o4\n=jRYg\n-----END PGP SIGNATURE-----\n',
#     'payload': 'tree 7caa32961a33f35f6c482d6331f7e2c1a6ac27fa\nparent f4b3c90886bbed58694ccfa2f56db9caddea3417\nauthor Erick Friis <erick@langchain.dev> 1724270035 -0700\ncommitter GitHub <noreply@github.com> 1724270035 -0700\n\npartners/unstructured: release 0.1.2 (#25637)\n\n'}},
#   'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/c8be0a9f7071f9143636a1c29e0582ccb1dc5039',
#   'html_url': 'https://github.com/langchain-ai/langchain/commit/c8be0a9f7071f9143636a1c29e0582ccb1dc5039',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/commits/c8be0a9f7071f9143636a1c29e0582ccb1dc5039/comments',
#   'author': {'login': 'efriis',
#    'id': 9557659,
#    'node_id': 'MDQ6VXNlcjk1NTc2NTk=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/9557659?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/efriis',
#    'html_url': 'https://github.com/efriis',
#    'followers_url': 'https://api.github.com/users/efriis/followers',
#    'following_url': 'https://api.github.com/users/efriis/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/efriis/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/efriis/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/efriis/subscriptions',
#    'organizations_url': 'https://api.github.com/users/efriis/orgs',
#    'repos_url': 'https://api.github.com/users/efriis/repos',
#    'events_url': 'https://api.github.com/users/efriis/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/efriis/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'parents': [{'sha': 'f4b3c90886bbed58694ccfa2f56db9caddea3417',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/f4b3c90886bbed58694ccfa2f56db9caddea3417',
#     'html_url': 'https://github.com/langchain-ai/langchain/commit/f4b3c90886bbed58694ccfa2f56db9caddea3417'}]},
#  {'sha': 'f4b3c90886bbed58694ccfa2f56db9caddea3417',
#   'node_id': 'C_kwDOIPDwltoAKGY0YjNjOTA4ODZiYmVkNTg2OTRjY2ZhMmY1NmRiOWNhZGRlYTM0MTc',
#   'commit': {'author': {'name': 'Bagatur',
#     'email': '22008038+baskaryan@users.noreply.github.com',
#     'date': '2024-08-21T19:38:53Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2024-08-21T19:38:53Z'},
#    'message': 'docs: add prereq commas (#25626)',
#    'tree': {'sha': '0a28c57b7ad25b9df59bd9af18b199867fd2040e',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees/0a28c57b7ad25b9df59bd9af18b199867fd2040e'},
#    'url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits/f4b3c90886bbed58694ccfa2f56db9caddea3417',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
# ...
#    'subscriptions_url': 'https://api.github.com/users/efriis/subscriptions',
#    'organizations_url': 'https://api.github.com/users/efriis/orgs',
#    'repos_url': 'https://api.github.com/users/efriis/repos',
#    'events_url': 'https://api.github.com/users/efriis/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/efriis/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'parents': [{'sha': '3e296e39c8739cffe91d117e28d5fa99b97ec129',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/3e296e39c8739cffe91d117e28d5fa99b97ec129',
#     'html_url': 'https://github.com/langchain-ai/langchain/commit/3e296e39c8739cffe91d117e28d5fa99b97ec129'}]},
#  {'sha': '3e296e39c8739cffe91d117e28d5fa99b97ec129',
#   'node_id': 'C_kwDOIPDwltoAKDNlMjk2ZTM5Yzg3MzljZmZlOTFkMTE3ZTI4ZDVmYTk5Yjk3ZWMxMjk',
#   'commit': {'author': {'name': 'Bagatur',
#     'email': '22008038+baskaryan@users.noreply.github.com',
#     'date': '2024-08-20T18:08:24Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2024-08-20T18:08:24Z'},
#    'message': 'docs: update examples in api ref (#25589)',
#    'tree': {'sha': '57c231820a93317b055598d34708b365c268b664',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees/57c231820a93317b055598d34708b365c268b664'},
#    'url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits/3e296e39c8739cffe91d117e28d5fa99b97ec129',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\nHJ99hgh0TrTYCCW+28KC\n=bp9a\n-----END PGP SIGNATURE-----\n',
#     'payload': 'tree 57c231820a93317b055598d34708b365c268b664\nparent d40bdd6257ff49beab0d10998fd94513ee80bfd7\nauthor Bagatur <22008038+baskaryan@users.noreply.github.com> 1724177304 -0700\ncommitter GitHub <noreply@github.com> 1724177304 -0700\n\ndocs: update examples in api ref (#25589)\n\n'}},
#   'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/3e296e39c8739cffe91d117e28d5fa99b97ec129',
#   'html_url': 'https://github.com/langchain-ai/langchain/commit/3e296e39c8739cffe91d117e28d5fa99b97ec129',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/commits/3e296e39c8739cffe91d117e28d5fa99b97ec129/comments',
#   'author': {'login': 'baskaryan',
#    'id': 22008038,
#    'node_id': 'MDQ6VXNlcjIyMDA4MDM4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22008038?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/baskaryan',
#    'html_url': 'https://github.com/baskaryan',
#    'followers_url': 'https://api.github.com/users/baskaryan/followers',
#    'following_url': 'https://api.github.com/users/baskaryan/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/baskaryan/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/baskaryan/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/baskaryan/subscriptions',
#    'organizations_url': 'https://api.github.com/users/baskaryan/orgs',
#    'repos_url': 'https://api.github.com/users/baskaryan/repos',
#    'events_url': 'https://api.github.com/users/baskaryan/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/baskaryan/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'parents': [{'sha': 'd40bdd6257ff49beab0d10998fd94513ee80bfd7',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/d40bdd6257ff49beab0d10998fd94513ee80bfd7',
#     'html_url': 'https://github.com/langchain-ai/langchain/commit/d40bdd6257ff49beab0d10998fd94513ee80bfd7'}]},
#  {'sha': 'd40bdd6257ff49beab0d10998fd94513ee80bfd7',
#   'node_id': 'C_kwDOIPDwltoAKGQ0MGJkZDYyNTdmZjQ5YmVhYjBkMTA5OThmZDk0NTEzZWU4MGJmZDc',
#   'commit': {'author': {'name': 'Isaac Francisco',
#     'email': '78627776+isahers1@users.noreply.github.com',
#     'date': '2024-08-20T17:54:42Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2024-08-20T17:54:42Z'},
#    'message': 'docs: more indexing of document loaders (#25500)\n\nCo-authored-by: Bagatur <baskaryan@gmail.com>\r\nCo-authored-by: Bagatur <22008038+baskaryan@users.noreply.github.com>',
#    'tree': {'sha': 'eaff4e6bc66c0589a86e09fdc0f1abd392fa9eed',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees/eaff4e6bc66c0589a86e09fdc0f1abd392fa9eed'},
#    'url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits/d40bdd6257ff49beab0d10998fd94513ee80bfd7',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\nzXaHSplYYbybw1DhVnuU\n=Q8qT\n-----END PGP SIGNATURE-----\n',
#     'payload': 'tree eaff4e6bc66c0589a86e09fdc0f1abd392fa9eed\nparent 8a71f1b41b83a4c8122ca53306fb09400ef5b537\nauthor Isaac Francisco <78627776+isahers1@users.noreply.github.com> 1724176482 -0700\ncommitter GitHub <noreply@github.com> 1724176482 +0000\n\ndocs: more indexing of document loaders (#25500)\n\nCo-authored-by: Bagatur <baskaryan@gmail.com>\r\nCo-authored-by: Bagatur <22008038+baskaryan@users.noreply.github.com>'}},
#   'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/d40bdd6257ff49beab0d10998fd94513ee80bfd7',
#   'html_url': 'https://github.com/langchain-ai/langchain/commit/d40bdd6257ff49beab0d10998fd94513ee80bfd7',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/commits/d40bdd6257ff49beab0d10998fd94513ee80bfd7/comments',
#   'author': {'login': 'isahers1',
#    'id': 78627776,
#    'node_id': 'MDQ6VXNlcjc4NjI3Nzc2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/78627776?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/isahers1',
#    'html_url': 'https://github.com/isahers1',
#    'followers_url': 'https://api.github.com/users/isahers1/followers',
#    'following_url': 'https://api.github.com/users/isahers1/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/isahers1/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/isahers1/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/isahers1/subscriptions',
#    'organizations_url': 'https://api.github.com/users/isahers1/orgs',
#    'repos_url': 'https://api.github.com/users/isahers1/repos',
#    'events_url': 'https://api.github.com/users/isahers1/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/isahers1/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'parents': [{'sha': '8a71f1b41b83a4c8122ca53306fb09400ef5b537',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/8a71f1b41b83a4c8122ca53306fb09400ef5b537',
#     'html_url': 'https://github.com/langchain-ai/langchain/commit/8a71f1b41b83a4c8122ca53306fb09400ef5b537'}]},
#  {'sha': '8a71f1b41b83a4c8122ca53306fb09400ef5b537',
#   'node_id': 'C_kwDOIPDwltoAKDhhNzFmMWI0MWI4M2E0YzgxMjJjYTUzMzA2ZmIwOTQwMGVmNWI1Mzc',
#   'commit': {'author': {'name': 'Bagatur',
#     'email': '22008038+baskaryan@users.noreply.github.com',
#     'date': '2024-08-20T17:22:14Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2024-08-20T17:22:14Z'},
#    'message': 'core[minor]: add langsmith document loader (#25493)\n\nneeds tests',
#    'tree': {'sha': 'f236467de60f65e28e7c92b88d56f1e1a78f3ecf',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees/f236467de60f65e28e7c92b88d56f1e1a78f3ecf'},
#    'url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits/8a71f1b41b83a4c8122ca53306fb09400ef5b537',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\nX7aSh8wcot7GHoiVCi2h\n=L8l5\n-----END PGP SIGNATURE-----\n',
#     'payload': 'tree f236467de60f65e28e7c92b88d56f1e1a78f3ecf\nparent 8e3e532e7dd62f4cc61753baa5954692b6cc0bb7\nauthor Bagatur <22008038+baskaryan@users.noreply.github.com> 1724174534 -0700\ncommitter GitHub <noreply@github.com> 1724174534 -0700\n\ncore[minor]: add langsmith document loader (#25493)\n\nneeds tests'}},
#   'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/8a71f1b41b83a4c8122ca53306fb09400ef5b537',
#   'html_url': 'https://github.com/langchain-ai/langchain/commit/8a71f1b41b83a4c8122ca53306fb09400ef5b537',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/commits/8a71f1b41b83a4c8122ca53306fb09400ef5b537/comments',
#   'author': {'login': 'baskaryan',
#    'id': 22008038,
#    'node_id': 'MDQ6VXNlcjIyMDA4MDM4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22008038?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/baskaryan',
#    'html_url': 'https://github.com/baskaryan',
#    'followers_url': 'https://api.github.com/users/baskaryan/followers',
#    'following_url': 'https://api.github.com/users/baskaryan/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/baskaryan/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/baskaryan/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/baskaryan/subscriptions',
#    'organizations_url': 'https://api.github.com/users/baskaryan/orgs',
#    'repos_url': 'https://api.github.com/users/baskaryan/repos',
#    'events_url': 'https://api.github.com/users/baskaryan/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/baskaryan/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'parents': [{'sha': '8e3e532e7dd62f4cc61753baa5954692b6cc0bb7',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/8e3e532e7dd62f4cc61753baa5954692b6cc0bb7',
#     'html_url': 'https://github.com/langchain-ai/langchain/commit/8e3e532e7dd62f4cc61753baa5954692b6cc0bb7'}]}]

# %% [markdown]
# ## 解析导出每日进展
#
# API 请求返回结构过于复杂，我们先解析 `title` 字段，即仅查看和总结 GitHub 项目 Issues list 和 PRs List 标题。如下所示：
#
# ![Issues](images/issues.png)
#
# https://github.com/langchain-ai/langchain/issues

# %%
github_client.export_daily_progress(repo)
# Out:
# Exported daily progress to langchain-ai_langchain_2024-08-22.md
# 'langchain-ai_langchain_2024-08-22.md'

# %% [markdown]
# ### 查看文档 发现问题并不简单😈😈
#
# #### Note: Every pull request is an issue
#
# > GitHub's REST API considers every pull request an issue, but not every issue is a pull request. For this reason, "Issues" endpoints may return both issues and pull requests in the response. You can identify pull requests by the pull_request key. Be aware that the id of a pull request returned from "Issues" endpoints will be an issue id. To find out the pull request id, use the "List pull requests" endpoint.

# %% [markdown]
# # 支持条件筛选的 GitHub 项目进展获取
#
# 实际开发场景中，项目进展通常不是刚好以天为周期时。因此，这便暴露出v0.2版本的 `GitHubClient` 在信息获取方面的局限性。
#
#
# 下面我们扩展 v0.2 版本的 `GitHubClient`，使其支持根据筛选条件获取 GitHub 项目的 Issues 和 Pull Requests。首要支持的筛选条便是**研发周期（时间段）**，**已合并的PR** 和 **已关闭的Issues**：
#
# ![langchain_week_progress](images/langchain_week_progress.jpg)
#
# 通过阅读 GitHub API 文档（https://docs.github.com/en/rest/issues/issues?apiVersion=2022-11-28#list-repository-issues--code-samples ），我们便能了解最关键的2个字段是：
#
# - state(string): Indicates the state of the issues to return.
#     - Default: open
#     - Can be one of: open, closed, all
# - since(string): Only show results that were last updated after the given time. This is a timestamp in ISO 8601 format: YYYY-MM-DDTHH:MM:SSZ.
#
# 从功能完整性角度，我们还可以增加一个 `until` 条件，以支持研发周期的结束时间筛选。😈😈
#
#
# 下面以 Langchain 项目 (https://github.com/langchain-ai/langchain) 为例，展示如何使用扩展后的 GitHubClient
#
# ## [v0.3] GitHubClient Class

# %%
# src/logger.py
from loguru import logger
import sys

# Configure Loguru
logger.remove()  # Remove the default logger
logger.add(sys.stdout, level="DEBUG", format="{time} {level} {message}", colorize=True)
logger.add("logs/app.log", rotation="1 MB", level="DEBUG")

# Alias the logger for easier import
LOG = logger

# Make the logger available for import with the alias
__all__ = ["LOG"]


# src/github_client.py

import requests  # 导入requests库用于HTTP请求
from datetime import datetime, date, timedelta  # 导入日期处理模块
import os  # 导入os模块用于文件和目录操作
# from logger import LOG  # 导入日志模块（演示时直接导入）

class GitHubClient:
    def __init__(self, token):
        self.token = token  # GitHub API令牌
        self.headers = {'Authorization': f'token {self.token}'}  # 设置HTTP头部认证信息

    def fetch_updates(self, repo, since=None, until=None):
        # 获取指定仓库的更新，可以指定开始和结束日期
        updates = {
            'commits': self.fetch_commits(repo, since, until),  # 获取提交记录
            'issues': self.fetch_issues(repo, since, until),  # 获取问题
            'pull_requests': self.fetch_pull_requests(repo, since, until)  # 获取拉取请求
        }
        return updates

    def fetch_commits(self, repo, since=None, until=None):
        url = f'https://api.github.com/repos/{repo}/commits'  # 构建获取提交的API URL
        params = {}
        if since:
            params['since'] = since  # 如果指定了开始日期，添加到参数中
        if until:
            params['until'] = until  # 如果指定了结束日期，添加到参数中

        response = requests.get(url, headers=self.headers, params=params)
        response.raise_for_status()  # 检查请求是否成功
        return response.json()  # 返回JSON格式的数据

    def fetch_issues(self, repo, since=None, until=None):
        url = f'https://api.github.com/repos/{repo}/issues'  # 构建获取问题的API URL
        params = {
            'state': 'closed',  # 仅获取已关闭的问题
            'since': since,
            'until': until
        }
        response = requests.get(url, headers=self.headers, params=params)
        response.raise_for_status()
        return response.json()

    def fetch_pull_requests(self, repo, since=None, until=None):
        url = f'https://api.github.com/repos/{repo}/pulls'  # 构建获取拉取请求的API URL
        params = {
            'state': 'closed',  # 仅获取已合并的拉取请求
            'since': since,
            'until': until
        }
        response = requests.get(url, headers=self.headers, params=params)
        response.raise_for_status()
        return response.json()

    def export_daily_progress(self, repo):
        today = datetime.now().date().isoformat()  # 获取今天的日期
        updates = self.fetch_updates(repo, since=today)  # 获取今天的更新数据
        
        repo_dir = os.path.join('daily_progress', repo.replace("/", "_"))  # 构建存储路径
        os.makedirs(repo_dir, exist_ok=True)  # 确保目录存在
        
        file_path = os.path.join(repo_dir, f'{today}.md')  # 构建文件路径
        with open(file_path, 'w') as file:
            file.write(f"# Daily Progress for {repo} ({today})\n\n")
            file.write("\n## Issues Closed Today\n")
            for issue in updates['issues']:  # 写入今天关闭的问题
                file.write(f"- {issue['title']} #{issue['number']}\n")
            file.write("\n## Pull Requests Merged Today\n")
            for pr in updates['pull_requests']:  # 写入今天合并的拉取请求
                file.write(f"- {pr['title']} #{pr['number']}\n")
        
        LOG.info(f"Exported daily progress to {file_path}")  # 记录日志
        return file_path

    def export_progress_by_date_range(self, repo, days):
        today = date.today()  # 获取当前日期
        since = today - timedelta(days=days)  # 计算开始日期
        
        updates = self.fetch_updates(repo, since=since.isoformat(), until=today.isoformat())  # 获取指定日期范围内的更新
        
        repo_dir = os.path.join('daily_progress', repo.replace("/", "_"))  # 构建目录路径
        os.makedirs(repo_dir, exist_ok=True)  # 确保目录存在
        
        # 更新文件名以包含日期范围
        date_str = f"{since}_to_{today}"
        file_path = os.path.join(repo_dir, f'{date_str}.md')  # 构建文件路径
        
        with open(file_path, 'w') as file:
            file.write(f"# Progress for {repo} ({since} to {today})\n\n")
            file.write(f"\n## Issues Closed in the Last {days} Days\n")
            for issue in updates['issues']:  # 写入在指定日期内关闭的问题
                file.write(f"- {issue['title']} #{issue['number']}\n")
            file.write("\n## Pull Requests Merged in the Last {days} Days\n")
            for pr in updates['pull_requests']:  # 写入在指定日期内合并的拉取请求
                file.write(f"- {pr['title']} #{pr['number']}\n")
        
        LOG.info(f"Exported time-range progress to {file_path}")  # 记录日志
        return file_path

# %%
# 实例化 v0.3 版本的 GitHub Client
github_client = GitHubClient(token=os.getenv("GITHUB_TOKEN"))

# %% [markdown]
# ### 获取过去1天 LangChain 进展（已关闭的Issues）

# %%
# 获取今天的日期，从午夜开始，ISO 8601格式
today = datetime.now().replace(hour=0, minute=0, second=0, microsecond=0).isoformat()

# 获取今天关闭的Issues
closed_issues_today = github_client.fetch_issues(repo='langchain-ai/langchain', since=today, until=today)

# 打印今天关闭的Issues标题
for issue in closed_issues_today:
    print(f"Issue #{issue['number']}: {issue['title']} (关闭时间 {issue['closed_at']})")
# Out:
# Issue #20095: Stop Sequenced Not Supported by AWS Bedrock (关闭时间 2024-07-21T16:06:44Z)

# %%
# 获取过去3天的日期
three_days_ago = datetime.now() - timedelta(days=3)
three_days_ago = three_days_ago.replace(hour=0, minute=0, second=0, microsecond=0).isoformat()

# 获取过去3天关闭的Issues
closed_issues_last_3_days = github_client.fetch_issues(repo='langchain-ai/langchain', since=three_days_ago, until=today)

# 打印过去3天关闭的Issues标题
for issue in closed_issues_last_3_days:
    print(f"Issue #{issue['number']}: {issue['title']} (关闭时间 {issue['closed_at']})")
# Out:
# Issue #25642: docs: ls similar examples header (关闭时间 2024-08-21T20:50:25Z)
# Issue #25641: chroma: add back fastapi optional dep (关闭时间 2024-08-21T20:00:48Z)
# Issue #25640: docs: link Versions in intro (关闭时间 2024-08-21T21:02:25Z)
# Issue #25639: docs: fix openai api ref (关闭时间 2024-08-21T19:55:17Z)
# Issue #25638: Use 1.101 instead of 1.100 bc 1.100 was yanked (关闭时间 2024-08-21T21:02:01Z)
# Issue #25637: partners/unstructured: release 0.1.2 (关闭时间 2024-08-21T19:53:55Z)
# Issue #25634: core[patch]: dont update run names in tracer (关闭时间 2024-08-21T19:56:03Z)
# Issue #25633: box: add retrievers and fix docs (关闭时间 2024-08-21T22:40:40Z)
# Issue #25632: infra: test convert_message (关闭时间 2024-08-21T18:24:06Z)
# Issue #25626: docs: add prereq commas (关闭时间 2024-08-21T19:38:53Z)
# Issue #25624: docs: ls how to link (关闭时间 2024-08-21T17:18:08Z)
# Issue #25623: docs: langsmith few shot prereq (关闭时间 2024-08-21T16:44:25Z)
# Issue #25622: core[patch]: Release 0.2.34 (关闭时间 2024-08-21T16:26:51Z)
# Issue #25621: core[patch]: support oai dicts as messages (关闭时间 2024-08-21T16:13:15Z)
# Issue #25619: together[patch]: use mixtral in standard integration tests (关闭时间 2024-08-21T14:26:26Z)
# Issue #25616: docs: Update qdrant.ipynb "BM25".lower() (关闭时间 2024-08-21T13:45:00Z)
# Issue #25612: docs:Correcting spelling mistakes (关闭时间 2024-08-21T12:49:12Z)
# Issue #25605: Improvement[Doc] Improve api doc in of `PineconeVectorStore` (关闭时间 2024-08-21T12:58:00Z)
# Issue #25601: docs: how to use langsmith few shot (关闭时间 2024-08-21T15:12:42Z)
# Issue #25600: docs: migration guide nits (关闭时间 2024-08-22T04:24:34Z)
# Issue #25599: partners/chroma: release 0.1.3 (关闭时间 2024-08-20T23:24:33Z)
# Issue #25596: docs: few-shot conceptual guide (关闭时间 2024-08-21T00:39:50Z)
# Issue #25593: [Community][minor]: Updating metadata with full_path in SharePoint loader (关闭时间 2024-08-21T13:10:15Z)
# Issue #25589: docs: update examples in api ref (关闭时间 2024-08-20T18:08:24Z)
# Issue #25586: chroma: ban chromadb sdk versions 0.5.4 and 0.5.5 due to pydantic bug (关闭时间 2024-08-20T23:21:39Z)
# Issue #25584: chroma: fix typing (关闭时间 2024-08-20T23:18:59Z)
# Issue #25579: v0.1 docs: add callout to OllamaFunctions docs (关闭时间 2024-08-20T12:59:12Z)
# Issue #25577: Update azuresearch.py (关闭时间 2024-08-20T12:53:31Z)
# Issue #25568: create_tool_calling_agent only return tool result in json instead of a straightfoward answer (关闭时间 2024-08-20T17:02:02Z)
# Issue #25564: create_tool_calling_agent is not working for AzureChatOpenAI (关闭时间 2024-08-20T13:52:57Z)

# %% [markdown]
# ## 优化导出文件管理
#
# 考虑到 GitHubSentinel 项目长期运行将会生成一大批项目进展文件，因此将所有进展文件统一存储在`daily_progress` 目录下，并按照 `{owners}_{repo}/{since_day}_{until_day}.md` 方式命名。
#
# 如下所示：
#
# ```shell
# daily_progress
# ├── langchain-ai_langchain
# │   ├── 2024-08-04.md
# │   ├── 2024-08-04_report.md
# │   ├── 2024-08-18.md
# │   └── 2024-08-18_report.md
# ├── llm_logs.log
# ├── ollama_ollama
# │   ├── 2024-07-30_to_2024-08-04.md
# │   ├── 2024-07-30_to_2024-08-04_report.md
# │   ├── 2024-08-02_to_2024-08-04.md
# │   ├── 2024-08-02_to_2024-08-04_report.md
# │   ├── 2024-08-04.md
# │   └── 2024-08-04_report.md
# ```

# %%
github_client.export_progress_by_date_range(repo='langchain-ai/langchain', days=3)
# Out:
# 2024-08-22T15:44:47.942536+0800 INFO Exported time-range progress to daily_progress\langchain-ai_langchain\2024-08-19_to_2024-08-22.md
# 'daily_progress\\langchain-ai_langchain\\2024-08-19_to_2024-08-22.md'

# %%
github_client.export_daily_progress(repo='langchain-ai/langchain')
# Out:
# 2024-08-22T15:46:01.177985+0800 INFO Exported daily progress to daily_progress\langchain-ai_langchain\2024-08-22.md
# 'daily_progress\\langchain-ai_langchain\\2024-08-22.md'

# %% [markdown]
# ### Homework: [可选] 尝试扩展 GitHubClient，使其支持 Since + Until 参数的特定时间段筛选
# ![image.png](attachment:12c41fc1-1001-4b5c-9905-131457956a2e.png)![image.png](attachment:532f2f6e-17e4-4d49-934e-d7301d9e8d9b.png)![image.png](attachment:d7c01738-e689-409e-b9aa-476cad3f8220.png)![image.png](attachment:bd00a348-af22-4a69-b64d-5f676f9ed7ee.png)
